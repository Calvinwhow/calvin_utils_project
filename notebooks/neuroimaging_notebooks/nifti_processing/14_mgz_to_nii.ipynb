# %% [markdown]
# Convert a .mgz file to a .nii.gz file

# %%
file_structure = '/Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/*/mri/brain.mgz'

# %%
from calvin_utils.file_utils.mgz_to_nii import mgz_to_nii
mgz_to_nii(file_structure)
# Out:
# /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/001/mri/brain.mgz
# Converted: /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/001/mri/brain.mgz -> /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/001/mri/brain.nii.gz
# /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/002/mri/brain.mgz
# Converted: /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/002/mri/brain.mgz -> /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/002/mri/brain.nii.gz
# /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/003/mri/brain.mgz
# Converted: /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/003/mri/brain.mgz -> /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/003/mri/brain.nii.gz
# /Volumes/HowExp/datasets/01d_RimonaWeil_DLB_Atrophy/derivatives/004/mri/brain.mgz
# ...
