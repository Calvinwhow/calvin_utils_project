# %% [markdown]
# # 01 - Define Paths

# %% [markdown]
# Nifti 1 Information

# %%
nifti_path_1 = '/Users/cu135/Dropbox (Partners HealthCare)/resources/atlases/mni_lobe_atlas/mni_Cortex.nii'
nifti_1_threshold = 0
nifti_1_threshold_direction='keep_above'

# %% [markdown]
# Nifti 2 Information

# %%
nifti_path_2 = '/Users/cu135/Dropbox (Partners HealthCare)/resources/mni_spaces/6th_gen/mni_152_gm_mask_resampled_binary.nii'
nifti_2_threshold = 0
nifti_2_threshold_direction='keep_above'

# %% [markdown]
# # 02 - Define Output Information

# %%
out_directory = '/Users/cu135/Dropbox (Partners HealthCare)/resources/mni_spaces/6th_gen'
filename = 'mni_152_cortex_mask'

# %% [markdown]
# # 03 - Run the Conjunction Analysis

# %%
from calvin_utils.nifti_utils.conjunction_analysis import ConjunctionMap

conjunction_mapper = ConjunctionMap(nift_path_1=nifti_path_1, 
                                    nift_path_2=nifti_path_2, 
                                    threshold1=nifti_1_threshold, 
                                    threshold2=nifti_2_threshold, 
                                    direction1=nifti_1_threshold_direction, 
                                    direction2=nifti_2_threshold_direction, 
                                    mask_path=None, 
                                    output_dir=out_directory, 
                                    output_name=filename)
html_img = conjunction_mapper.run()
html_img
