# %% [markdown]
# # 01 - Find Files

# %% [markdown]
# **Search for the Files**
# _______
# Formatting the Directory-Pattern Dictionary
# The function glob_multiple_file_paths expects a dictionary where each key-value pair corresponds to a root directory and a file pattern to search within that directory. The keys are the root directories where you want to start the search, and the values are the file patterns to match against.
#
# Example Dictionary Format:
#
# >dir_pattern_dict = {
# >    '/path/to/first/root_dir': '*.nii',
# >
# >    '/path/to/second/root_dir': '*.nii.gz',
# >
# >    '/another/path': '*_label.nii'
# >     Add more key-value pairs as needed
# >}
#
# Using Wildcards:
#
# The file patterns can include wildcards to match multiple files:
# - *: Matches zero or more characters
# - **: Searches all directories recursively
# - *.nii will match all files ending with .nii
# - ?: Matches any single character
# - file?.nii will match file1.nii, file2.nii, etc.
# - [seq]: Matches any character in seq
# - file[1-3].nii will match file1.nii, file2.nii, file3.nii
# - [!seq]: Matches any character NOT in seq
# - file[!1-3].nii will match any file that doesn't have 1, 2, or 3 in that position, like file4.nii, file5.nii, etc.
#
# Feel free to combine these wildcards to create complex file patterns. For example, *_??.nii will match files like file_01.nii, file_02.nii, etc.

# %% [markdown]
# Where to Save to

# %%
out_dir = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/BIDS_PD_DBS_STN_WURZBURG/metadata'
filename = 'clinicalscores_tremor_for_tremor-mapping.csv'

# %%
# Define the dictionary with root directories and file patterns
dir_pattern_dict = {
    '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/BIDS_PD_DBS_STN_WURZBURG/derivatives/third_level/vtasCompoundMNI152': '*Precom*_T*.nii*'}

# %% [markdown]
# ## Glob the files and check to see if acceptable

# %%
save_files = False

# %%
from calvin_utils.file_utils.file_path_collector import glob_multiple_file_paths
import os
# Validate Directory
# os.mkdir(os.path.dirname(csv_path))
# Call the function and save the returned DataFrame to a CSV file
path_df = glob_multiple_file_paths(dir_pattern_dict, save=save_files, save_path=None)

# Display the saved path and the DataFrame
display(path_df)
# Out:
#                                                 paths
# 0   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 1   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 2   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 3   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 4   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 5   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 6   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 7   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 8   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 9   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 10  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 11  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 12  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 13  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 14  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 15  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 16  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 17  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 18  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 19  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 20  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 21  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 22  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 23  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 24  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 25  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 26  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 27  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 28  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 29  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 30  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 31  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 32  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 33  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 34  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 35  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 36  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 37  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 38  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 39  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 40  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 41  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 42  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 43  /Users/cu135/Partners HealthCare Dropbox/Calvi...

# %% [markdown]
# # Option 2 - Extract Subject IDs

# %%
# Define the preceding and proceeding strings
preceding = 'MNI152/'
proceeding = '_seed'

# Extract the substring and add it to a new column 'subject'
path_df['subject'] = path_df['paths'].str.extract(f'{preceding}(.*?){proceeding}')

# Display the updated DataFrame
display(path_df)
# Out:
#                                                 paths subject
# 0   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST10
# 1   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST09
# 2   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST02
# 3   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST34
# 4   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST26
# 5   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST41
# 6   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST20
# 7   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST39
# 8   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST32
# 9   /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST04
# 10  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST16
# 11  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST11
# 12  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST08
# 13  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST03
# 14  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST35
# 15  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST27
# 16  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST40
# 17  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST21
# 18  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST38
# 19  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST33
# 20  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST05
# 21  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST17
# 22  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST12
# 23  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST19
# 24  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST36
# 25  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST24
# 26  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST22
# 27  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST43
# 28  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST29
# 29  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST30
# 30  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST06
# 31  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST14
# 32  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST13
# 33  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST18
# 34  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST01
# 35  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST37
# 36  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST44
# 37  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST25
# 38  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST23
# 39  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST28
# 40  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST42
# 41  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST31
# 42  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST07
# 43  /Users/cu135/Partners HealthCare Dropbox/Calvi...  MDST15

# %% [markdown]
# # 03 Option A - Import Another CSV and Add the Paths to It
# **The CSV is expected to be in this format**
# - ID and absolute paths to niftis are critical
# ```
# +-----+----------------------------+--------------+--------------+--------------+
# | ID  | Nifti_File_Path            | Covariate_1  | Covariate_2  | Covariate_3  |
# +-----+----------------------------+--------------+--------------+--------------+
# | 1   | /path/to/file1.nii.gz      | 0.5          | 1.2          | 3.4          |
# | 2   | /path/to/file2.nii.gz      | 0.7          | 1.4          | 3.1          |
# | 3   | /path/to/file3.nii.gz      | 0.6          | 1.5          | 3.5          |
# | 4   | /path/to/file4.nii.gz      | 0.9          | 1.1          | 3.2          |
# | ... | ...                        | ...          | ...          | ...          |
# +-----+----------------------------+--------------+--------------+--------------+
# ```

# %%
spreadsheet_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/BIDS_PD_DBS_STN_WURZBURG/metadata/clinicalscores_tremor_for_tremor-mapping.csv'
sheet = None #If using Excel, enter a string here

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=spreadsheet_path, output_dir=os.path.dirname(spreadsheet_path), sheet=sheet)
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()
data_df
# Out:
#    subject  baseline  postop  tremor_improvement  path  \
# 0   MDST01       9.0     0.0                 9.0   NaN
# 1   MDST02       2.0     2.0                 0.0   NaN
# 2   MDST03       2.0     0.0                 2.0   NaN
# 3   MDST04       NaN     NaN                 NaN   NaN
# 4   MDST05       4.0     9.0                -5.0   NaN
# 5   MDST06       4.0     0.0                 4.0   NaN
# 6   MDST07       NaN     NaN                 NaN   NaN
# 7   MDST09       NaN     NaN                 NaN   NaN
# 8   MDST11      14.0     0.0                14.0   NaN
# 9   MDST12       NaN     NaN                 NaN   NaN
# 10  MDST14       NaN     NaN                 NaN   NaN
# 11  MDST15      14.0     7.0                 7.0   NaN
# 12  MDST16      19.0     2.0                17.0   NaN
# 13  MDST17       9.0     0.0                 9.0   NaN
# 14  MDST18       NaN     NaN                 NaN   NaN
# 15  MDST19       5.0     0.0                 5.0   NaN
# 16  MDST21       NaN     NaN                 NaN   NaN
# 17  MDST22       5.0     1.0                 4.0   NaN
# 18  MDST23       NaN     NaN                 NaN   NaN
# 19  MDST24       NaN     NaN                 NaN   NaN
# 20  MDST26      10.0     0.0                10.0   NaN
# 21  MDST27       2.0     0.0                 2.0   NaN
# 22  MDST28       NaN     NaN                 NaN   NaN
# 23  MDST29       NaN     NaN                 NaN   NaN
# 24  MDST30       4.0     0.0                 4.0   NaN
# 25  MDST31       NaN     NaN                 NaN   NaN
# 26  MDST33       NaN     NaN                 NaN   NaN
# 27  MDST34      17.0     5.0                12.0   NaN
# 28  MDST35      12.0     0.0                12.0   NaN
# 29  MDST36      19.0     5.0                14.0   NaN
# 30  MDST37       3.0     3.0                 0.0   NaN
# 31  MDST38       NaN     NaN                 NaN   NaN
# 32  MDST39       NaN     NaN                 NaN   NaN
# 33  MDST41       8.0     2.0                 6.0   NaN
# 34  MDST42       9.0     4.0                 5.0   NaN
# 35  MDST43       6.0     2.0                 4.0   NaN
# 36  MDST44       NaN     NaN                 NaN   NaN
#
#                                                 paths
# 0   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 1   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 2   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 3   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 4                                             MISSING
# 5   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 6   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 7   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 8   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 9   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 10  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 11  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 12                                            MISSING
# 13  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 14  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 15  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 16  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 17  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 18  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 19  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 20  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 21  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 22  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 23  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 24  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 25  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 26  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 27  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 28                                            MISSING
# 29  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 30  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 31  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 32  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 33                                            MISSING
# 34                                            MISSING
# 35  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 36  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...

# %%
merged_df = data_df.merge(path_df, on='subject', how='outer', suffixes=('', '_pathdf'))
display(merged_df)
# Out:
#    subject  baseline  postop  tremor_improvement  path  \
# 0   MDST01       9.0     0.0                 9.0   NaN
# 1   MDST02       2.0     2.0                 0.0   NaN
# 2   MDST03       2.0     0.0                 2.0   NaN
# 3   MDST04       NaN     NaN                 NaN   NaN
# 4   MDST05       4.0     9.0                -5.0   NaN
# 5   MDST06       4.0     0.0                 4.0   NaN
# 6   MDST07       NaN     NaN                 NaN   NaN
# 7   MDST08       NaN     NaN                 NaN   NaN
# 8   MDST09       NaN     NaN                 NaN   NaN
# 9   MDST10       NaN     NaN                 NaN   NaN
# 10  MDST11      14.0     0.0                14.0   NaN
# 11  MDST12       NaN     NaN                 NaN   NaN
# 12  MDST13       NaN     NaN                 NaN   NaN
# 13  MDST14       NaN     NaN                 NaN   NaN
# 14  MDST15      14.0     7.0                 7.0   NaN
# 15  MDST16      19.0     2.0                17.0   NaN
# 16  MDST17       9.0     0.0                 9.0   NaN
# 17  MDST18       NaN     NaN                 NaN   NaN
# 18  MDST19       5.0     0.0                 5.0   NaN
# 19  MDST20       NaN     NaN                 NaN   NaN
# 20  MDST21       NaN     NaN                 NaN   NaN
# 21  MDST22       5.0     1.0                 4.0   NaN
# 22  MDST23       NaN     NaN                 NaN   NaN
# 23  MDST24       NaN     NaN                 NaN   NaN
# 24  MDST25       NaN     NaN                 NaN   NaN
# 25  MDST26      10.0     0.0                10.0   NaN
# 26  MDST27       2.0     0.0                 2.0   NaN
# 27  MDST28       NaN     NaN                 NaN   NaN
# 28  MDST29       NaN     NaN                 NaN   NaN
# 29  MDST30       4.0     0.0                 4.0   NaN
# 30  MDST31       NaN     NaN                 NaN   NaN
# 31  MDST32       NaN     NaN                 NaN   NaN
# 32  MDST33       NaN     NaN                 NaN   NaN
# 33  MDST34      17.0     5.0                12.0   NaN
# 34  MDST35      12.0     0.0                12.0   NaN
# 35  MDST36      19.0     5.0                14.0   NaN
# 36  MDST37       3.0     3.0                 0.0   NaN
# 37  MDST38       NaN     NaN                 NaN   NaN
# 38  MDST39       NaN     NaN                 NaN   NaN
# 39  MDST40       NaN     NaN                 NaN   NaN
# 40  MDST41       8.0     2.0                 6.0   NaN
# 41  MDST42       9.0     4.0                 5.0   NaN
# 42  MDST43       6.0     2.0                 4.0   NaN
# 43  MDST44       NaN     NaN                 NaN   NaN
#
#                                                 paths  \
# 0   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 1   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 2   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 3   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 4                                             MISSING
# 5   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 6   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 7                                                 NaN
# 8   /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 9                                                 NaN
# 10  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 11  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 12                                                NaN
# 13  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 14  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 15                                            MISSING
# 16  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 17  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 18  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 19                                                NaN
# 20  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 21  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 22  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 23  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 24                                                NaN
# 25  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 26  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 27  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 28  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 29  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 30  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 31                                                NaN
# 32  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 33  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 34                                            MISSING
# 35  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 36  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 37  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 38  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 39                                                NaN
# 40                                            MISSING
# 41                                            MISSING
# 42  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
# 43  /Volumes/OneTouch/datasets/WURZBURG_PD_DBS_STN...
#
#                                          paths_pathdf
# 0   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 1   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 2   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 3   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 4   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 5   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 6   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 7   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 8   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 9   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 10  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 11  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 12  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 13  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 14  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 15  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 16  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 17  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 18  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 19  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 20  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 21  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 22  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 23  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 24  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 25  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 26  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 27  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 28  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 29  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 30  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 31  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 32  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 33  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 34  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 35  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 36  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 37  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 38  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 39  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 40  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 41  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 42  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 43  /Users/cu135/Partners HealthCare Dropbox/Calvi...

# %% [markdown]
# Rename Paths Column

# %%
newname = 'composite_paths'
merged_df = merged_df.rename(columns={'paths': newname})
display(merged_df)
# Out:
#          subject  roi_file_path  \
# 0     002_S_0295            NaN
# 1     002_S_0413            NaN
# 2     002_S_0559            NaN
# 3     002_S_0619            NaN
# 4     002_S_0685            NaN
# ...          ...            ...
# 1384  941_S_4365            NaN
# 1385  941_S_4376            NaN
# 1386  941_S_4377            NaN
# 1387  941_S_4420            NaN
# 1388  941_S_4764            NaN
#
#                                          conn_file_path        subu  \
# 0     /Volumes/Expansion/datasets/adni/neuroimaging/...  002uSu0295
# 1     /Volumes/Expansion/datasets/adni/neuroimaging/...  002uSu0413
# 2     /Volumes/Expansion/datasets/adni/neuroimaging/...  002uSu0559
# 3     /Volumes/Expansion/datasets/adni/neuroimaging/...  002uSu0619
# 4     /Volumes/Expansion/datasets/adni/neuroimaging/...  002uSu0685
# ...                                                 ...         ...
# 1384                                                NaN  941uSu4365
# 1385                                                NaN  941uSu4376
# 1386                                                NaN  941uSu4377
# 1387                                                NaN  941uSu4420
# 1388                                                NaN  941uSu4764
#
#             Age  Male  Female  CSF_Cerebellum  CSF_Subcortex      CSF_MTL  \
# 0     84.898630   1.0     0.0    -26319.38152     373.297842  -746.688684
# 1     76.397260   0.0     1.0    -13670.88871    5009.504947  -449.838607
# 2     79.410959   1.0     0.0    -38702.13792     152.392985  -754.706246
# 3     77.512329   1.0     0.0    -35472.21632  -23876.106190 -1947.061673
# 4     89.698630   0.0     1.0    -31092.93296  -22643.911490 -1014.786011
# ...         ...   ...     ...             ...            ...          ...
# 1384  80.410959   1.0     0.0    -38529.96216  -15404.929680  -662.636580
# 1385  76.594521   0.0     1.0    -17949.11453    -104.528538  -236.251734
# 1386  69.421918   0.0     1.0    -15992.36193    8601.241440   -63.774856
# 1387  81.493151   1.0     0.0    -16826.37025    -551.877244  -240.304833
# 1388  82.783562   0.0     1.0    -29967.55872   -4994.645463  -611.921947
#
#       ...  CSFGM_Cerebellum    CSFGM_MTL  CSFGM_Occipital  CSFGM_Frontal  \
# 0     ...      -42080.47385  -985.079574     -49948.08397  -112828.36320
# 1     ...      -31877.73761  -702.013806     -32065.48546   -86785.29415
# 2     ...      -59414.86617  -904.053254     -53596.47719  -105570.10190
# 3     ...      -53709.90879 -2423.897611     -73659.93022  -154724.05630
# 4     ...      -51590.80915 -1294.271075     -62190.93704   -99100.38722
# ...   ...               ...          ...              ...            ...
# 1384  ...      -57889.69365  -835.677343     -72888.69964  -129545.70420
# 1385  ...      -35263.89451  -633.850720     -61941.53743   -95745.37551
# 1386  ...      -37613.22065  -382.094253     -48520.90317   -83404.44082
# 1387  ...      -34028.22866  -420.608521     -45134.76002  -119449.11290
# 1388  ...      -48294.07464  -950.450008     -59456.54978  -132642.39670
#
#       CSFGM_Parietal  CSFGM_Temporal  \
# 0       -65321.06433    -81695.87251
# 1       -49161.42864    -58706.57030
# 2       -81075.10079    -72750.12881
# 3      -108539.66600   -121871.63710
# 4      -102677.31680    -86601.74343
# ...              ...             ...
# 1384    -96902.61918    -92846.76271
# 1385    -78969.66905    -67336.23936
# 1386    -60909.52233    -52907.83773
# 1387    -72759.32267    -77463.29364
# 1388    -83534.19419    -86640.54806
#
#                                               csf_paths  \
# 0     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 2     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 3     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 4     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# ...                                                 ...
# 1384  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1385  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1386  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1387  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1388  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
#
#                                                gm_paths  \
# 0     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 2     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 3     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 4     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# ...                                                 ...
# 1384  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1385  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1386  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1387  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1388  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
#
#                                                wm_paths  \
# 0     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 2     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 3     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 4     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# ...                                                 ...
# 1384  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1385  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1386  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1387  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1388  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
#
#                                         composite_paths
# 0     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 2     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 3     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 4     /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# ...                                                 ...
# 1384  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1385  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1386  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1387  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
# 1388  /Volumes/OneTouch/datasets/adni/neuroimaging/a...
#
# [1389 rows x 67 columns]

# %% [markdown]
# Save the merged df

# %%
merged_df.to_csv(spreadsheet_path, index=False)

# %% [markdown]
# # 03 Option B - Save Path DF To Its Own CSV

# %%
# import os
# os.makedirs(out_dir, exist_ok=True)
# path_df.to_csv(os.path.join(out_dir, filename), index=False)

# %% [markdown]
# Hope this was helpful
#
# --Calvin
