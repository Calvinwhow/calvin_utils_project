# %%
path_1 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/Jung_TMS_AD/metadata/memnet.csv'
path_2 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/Jung_TMS_AD/metadata/master_list_pre-post_scores.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df2
# Out:
#    subject treatment_group ktmte_parta_successfail_ ktmte_partb_successfail_  \
# 0      S05         control                  Success                  Success
# 1      S06         control                  Success                     Fail
# 2      S09       treatment                  Success                  Success
# 3      S10         control                  Success                  Success
# 4      S11       treatment                  Success                  Success
# 5      S12       treatment                  Success                  Success
# 6      S14         control                  Success                  Success
# 7      S15       treatment                  Success                  Success
# 8      S17         control                  Success                  Success
# 9      S18         control                  Success                     Fail
# 10     S19       treatment                  Success                  Success
# ...

# %%
merged_df = pd.merge(df1, df2, on='subject', how='outer')
merged_df
# Out:
#     Unnamed: 0 subject  optimized_convergent_map_best.nii.gz_cosine  \
# 0          0.0     S05                                          NaN
# 1          1.0     S06                                    -0.078945
# 2          2.0     S09                                    -0.029402
# 3          3.0     S10                                    -0.126209
# 4          4.0     S11                                    -0.070922
# 5          5.0     S12                                     0.023486
# 6          6.0     S14                                    -0.071181
# 7          7.0     S15                                    -0.049152
# 8          8.0     S17                                    -0.115634
# 9          9.0     S18                                    -0.077024
# 10        10.0     S19                                    -0.001030
# 11        11.0     S20                                    -0.051627
# 12        12.0     S21                                    -0.080573
# ...

# %%
merged_df.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/Jung_TMS_AD/metadata/memnet-plus-master.csv')
