# %%
path_1 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/DBS_studies_influencing_memory/metadata/master_list.csv'
path_2 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/DBS_studies_influencing_memory/metadata/optimal_map_ses-dbs_sub-all.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df2
# Out:
#                                              roi_path  \
# 0   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 1   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 2   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 3   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 4   /Users/cu135/Partners HealthCare Dropbox/Calvi...
# ..                                                ...
# 82  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 83  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 84  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 85  /Users/cu135/Partners HealthCare Dropbox/Calvi...
# 86  /Users/cu135/Partners HealthCare Dropbox/Calvi...
#
#     train_prune_test_performs_highly_spatial_corr  \
# 0                                       -0.001916
# 1                                       -0.002185
# 2                                       -0.000607
# 3                                       -0.005620
# 4                                       -0.005726
# ...

# %%
merged_df = pd.merge(df1, df2, on='roi_path', how='outer')
merged_df
# Out:
#               study        ses     N Memory_Outcome  \
# 0        Acera 2019     STN_BL  50.0       Improved
# 1        Asahi 2014     STN_BL  11.0       Impaired
# 2       Barcia 2022  Fornix_BL   1.0          Mixed
# 3     Bergfeld 2017   vALIC_BL  20.0       Impaired
# 4    Cabrera-Montes     STN_BL  20.0       Impaired
# ..              ...        ...   ...            ...
# 100   Williams 2011     STN_BL  19.0       Impaired
# 101      Woods 2002     STN_BL   NaN            NaN
# 102        You 2020     STN_BL   NaN            NaN
# 103  Zangaglia 2009     STN_BL  32.0       Impaired
# 104      Zhang 2021     BNM_BL   1.0            NaN
#
#      Pre_Post_Memory_Effect_Size__Cohen's_D_ Location  \
# 0                                   1.608530      STN
# 1                                  -6.380318      STN
# 2                                        NaN   Fornix
# 3                                  -0.246577    vALIC
# 4                                  -2.707720      STN
# ...

# %%
merged_df.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/DBS_studies_influencing_memory/metadata/master_list.csv', index=False)
