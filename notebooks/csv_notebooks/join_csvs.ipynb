# %%
path_1 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_seeds_2023/metadata/updated_with_all_adni/master_dx_updated_fix.csv'
path_2 = '/Volumes/Expansion/datasets/adni/neuroimaging/all_patients_atrophy_seeds/neuroimaging_analyses/ses-01/sub-all/0mm_zmap_atrophy_unthresholded_combo/*_csf-plus-gm.nii.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df2
# Out:
#            subid  CSFGM_Cerebellum    CSFGM_MTL  CSFGM_Occipital  \
# 0     002_S_0295      -42080.47385  -985.079574     -49948.08397
# 1     002_S_0413      -31877.73761  -702.013806     -32065.48546
# 2     002_S_0559      -59414.86617  -904.053254     -53596.47719
# 3     002_S_0619      -53709.90879 -2423.897611     -73659.93022
# 4     002_S_0685      -51590.80915 -1294.271075     -62190.93704
# ...          ...               ...          ...              ...
# 1300  941_S_4365      -57889.69365  -835.677343     -72888.69964
# 1301  941_S_4376      -35263.89451  -633.850720     -61941.53743
# 1302  941_S_4377      -37613.22065  -382.094253     -48520.90317
# 1303  941_S_4420      -34028.22866  -420.608521     -45134.76002
# 1304  941_S_4764      -48294.07464  -950.450008     -59456.54978
#
#       CSFGM_Frontal  CSFGM_Parietal  CSFGM_Temporal
# 0     -112828.36320    -65321.06433    -81695.87251
# 1      -86785.29415    -49161.42864    -58706.57030
# ...

# %%
merged_df = pd.merge(df1, df2, on='subid', how='outer')
merged_df
# Out:
#            subid        Age  Male  Female  CSF_Cerebellum  CSF_Subcortex  \
# 0     002_S_0295  84.898630   1.0     0.0    -26319.38152     373.297842
# 1     002_S_0413  76.397260   0.0     1.0    -13670.88871    5009.504947
# 2     002_S_0559  79.410959   1.0     0.0    -38702.13792     152.392985
# 3     002_S_0619  77.512329   1.0     0.0    -35472.21632  -23876.106190
# 4     002_S_0685  89.698630   0.0     1.0    -31092.93296  -22643.911490
# ...          ...        ...   ...     ...             ...            ...
# 1383  941_S_4365  80.410959   1.0     0.0    -38529.96216  -15404.929680
# 1384  941_S_4376  76.594521   0.0     1.0    -17949.11453    -104.528538
# 1385  941_S_4377  69.421918   0.0     1.0    -15992.36193    8601.241440
# 1386  941_S_4420  81.493151   1.0     0.0    -16826.37025    -551.877244
# 1387  941_S_4764  82.783562   0.0     1.0    -29967.55872   -4994.645463
#
#           CSF_MTL  CSF_Occipital   CSF_Frontal  CSF_Parietal  ...  \
# ...

# %%
# merged_df.pop('path')
merged_df.pop('Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /usr/local/Caskroom/mambaforge/base/envs/nimlab_py310/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
merged_df.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/atrophy_seeds_2023/metadata/updated_with_all_adni/master_dx_updated_fix_composite.csv')
