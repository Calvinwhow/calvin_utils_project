# %%
path_1 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/BIDS_AD_DBS_FORNIX/study_metadata/study_metadata/AD_Clinical_Data_CDR_ADAS_COG_13.csv'
path_2 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/BIDS_AD_DBS_FORNIX/study_metadata/study_metadata/BaselineMinusMonth12.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df1
# Out:
#       FNM_ID       Trial Randomization Arm  Patient # CDR, ADAS  Age at DOS  \
# 0   FNM01004   Advance-I         sham-stim                  101          62
# 1   FNM01007   Advance-I         stim-sham                  102          77
# 2   FNM01014   Advance-I         sham-stim                  103          76
# 3   FNM01006   Advance-I         stim-sham                  104          65
# 4        NaN       Pilot               NaN                  105          50
# 5   FNM01003   Advance-I         stim-sham                  106          66
# 6        NaN       Pilot               NaN                  107          64
# 7        NaN       Pilot               NaN                  108          60
# 8   FNM01009   Advance-I         sham-stim                  109          72
# 9   FNM01005   Advance-I         sham-stim                  110          72
# 10       NaN       Pilot               NaN                  111          62
# ...

# %%
merged_df = pd.merge(df1, df2, on='FNM_ID', how='outer')
merged_df
# Out:
#       FNM_ID             interval  ADAS11Score  ADAS13Score  \
# 0   FNM01001  Baseline - Month 12        -14.0        -14.0
# 1   FNM01002  Baseline - Month 12         -8.0         -6.0
# 2   FNM01003  Baseline - Month 12         -5.0         -5.0
# 3   FNM01004  Baseline - Month 12        -11.0        -12.0
# 4   FNM01005  Baseline - Month 12         -1.0          3.0
# ..       ...                  ...          ...          ...
# 58       NaN                  NaN          NaN          NaN
# 59       NaN                  NaN          NaN          NaN
# 60       NaN                  NaN          NaN          NaN
# 61       NaN                  NaN          NaN          NaN
# 62       NaN                  NaN          NaN          NaN
#
#     ADASCancellationCorrectScore  ADASCancellationIncorrectScore  \
# 0                           20.0                             0.0
# 1                          -10.0                            -1.0
# ...

# %%
merged_df.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/BIDS_AD_DBS_FORNIX/study_metadata/study_metadata/BaselineMinusMonth12_full.csv', index=False)
