# %%
path_1 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/TMS_studies_influencing_memory/metadata/tms_studies_influencing_memory.csv'
path_2 = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/TMS_studies_influencing_memory/metadata/Updated_DOI_and_PMID_Table.csv'

# %%
import pandas as pd
df1 = pd.read_csv(path_1)
df2 = pd.read_csv(path_2)
df1
# Out:
#                study              PMID  \
# 0       Jackson 2021               NaN
# 1    Turriziani 2012               NaN
# 2    Turriziani 2012               NaN
# 3    Turriziani 2012               NaN
# 4    Turriziani 2012               NaN
# ..               ...               ...
# 161         Xiu 2020               NaN
# 162        Yang 2019          30688320
# 163       Zhang 2019          30592150
# 164        Zhao 2017          28233717
# 165        Zhuo 2019  30581622 (2019)*
#
#                                                    DOI      ses    N  \
# 0                                                  NaN  dlPFC_R   20
# 1                                                  NaN      NaN  100
# 2                                                  NaN      NaN  100
# 3                                                  NaN      NaN  100
# 4                                                  NaN      NaN  100
# ..                                                 ...      ...  ...
# 161                                                NaN      NaN  110
# 162    10.1016/j.brs.2018.10.013 (Brain Stimul. 2019)*      NaN   52
# 163  10.1016/j.jalz.2018.12.009 (Alzheimers Dement ...      NaN   28
# 164        10.1016/j.cortex.2016.12.016 (Cortex 2017)*      NaN   30
# 165  10.1093/ijnp/pyy112 (Int J Neuropsychopharmaco...      NaN   60
#
#     Reported Outcome Pre-Post Memory Effect Size (Cohen's D) Location  \
# 0           Impaired                            -0.622389284    dlPFC
# 1              Mixed                            -0.738548946    dlPFC
# 2              Mixed                             0.443129368    dlPFC
# 3              Mixed                             0.073854895    dlPFC
# 4              Mixed                            -0.590839157    dlPFC
# ..               ...                                     ...      ...
# 161         Improved                                     NaN    dlPFC
# 162         Improved                                     NaN    DLPFC
# 163           UNSURE                                     NaN    motor
# 164           UNSURE                                     NaN    motor
# 165           UNSURE                                     NaN     mPFC
#
#     List of Coordinates Side  ... Unnamed: 34  experimental_post_mean  \
# 0          [44, 31, 28]    R  ...         NaN                    57.0
# 1         [-44, 31, 28]    L  ...         NaN                    57.0
# 2          [44, 31, 28]    R  ...         NaN                    73.0
# 3         [-44, 31, 28]    L  ...         NaN                    80.0
# 4          [44, 31, 28]    R  ...         NaN                    72.0
# ..                  ...  ...  ...         ...                     ...
# 161                 NaN  NaN  ...         NaN                     NaN
# 162                 NaN  NaN  ...         NaN                     NaN
# 163                 NaN  NaN  ...         NaN                     NaN
# 164                 NaN  NaN  ...         NaN                     NaN
# 165                 NaN  NaN  ...         NaN                     NaN
#
#      experimental_post_stdev  experimental_post_n  Unnamed: 38  Unnamed: 39  \
# 0                        5.0                 20.0          NaN          NaN
# 1                       10.0                100.0          NaN          NaN
# 2                       10.0                100.0          NaN          NaN
# 3                       10.0                100.0          NaN          NaN
# 4                       10.0                100.0          NaN          NaN
# ..                       ...                  ...          ...          ...
# 161                      NaN                  NaN          NaN          NaN
# 162                      NaN                  NaN          NaN          NaN
# 163                      NaN                  NaN          NaN          NaN
# 164                      NaN                  NaN          NaN          NaN
# 165                      NaN                  NaN          NaN          NaN
#
#      Unnamed: 40  Unnamed: 41  Unnamed: 42  Unnamed: 43
# 0            NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...
# 161          NaN          NaN          NaN          NaN
# 162          NaN          NaN          NaN          NaN
# 163          NaN          NaN          NaN          NaN
# 164          NaN          NaN          NaN          NaN
# 165          NaN          NaN          NaN          NaN
#
# [166 rows x 44 columns]

# %%
merged_df = pd.merge(df1, df2, on='study', how='outer')
merged_df
# Out:
#                    study    PMID_x                           DOI_x  ses    N  \
# 0             Ahmed 2012  21671144       10.1007/s00415-011-6128-4  NaN   45
# 1            Albouy 2017       NaN                             NaN  NaN   17
# 2    Alcalá-Lozano 2018  29329932       10.1016/j.brs.2017.12.011  NaN   19
# 3             Ameis 2020  32044029       10.1016/j.brs.2020.01.007  NaN   40
# 4             Avery 2006  16084813  10.1016/j.biopsych.2005.07.003  NaN   68
# ..                   ...       ...                             ...  ...  ...
# 161                  NaN       NaN                             NaN  NaN  NaN
# 162                  NaN       NaN                             NaN  NaN  NaN
# 163                  NaN       NaN                             NaN  NaN  NaN
# 164                  NaN       NaN                             NaN  NaN  NaN
# 165                  NaN       NaN                             NaN  NaN  NaN
#
#     Reported Outcome Pre-Post Memory Effect Size (Cohen's D)     Location  \
# 0           Improved                                     NaN   rightDLPFC
# 1           Improved                                     0.1     Parietal
# 2             UNSURE                                     NaN       UNSURE
# 3           Improved                                     NaN  right DLPFC
# 4             UNSURE                                     NaN        DLPFC
# ..               ...                                     ...          ...
# 161              NaN                                 #DIV/0!          NaN
# 162              NaN                                 #DIV/0!          NaN
# 163              NaN                                     NaN          NaN
# 164              NaN                                     NaN          NaN
# 165              NaN                                     NaN          NaN
#
#     List of Coordinates Side  ... experimental_post_stdev  \
# 0                   NaN  NaN  ...                     NaN
# 1        [-36, -60, 56]    L  ...                     NaN
# 2                   NaN  NaN  ...                     NaN
# 3                   NaN  NaN  ...                     NaN
# 4                   NaN  NaN  ...                     NaN
# ..                  ...  ...  ...                     ...
# 161                 NaN  NaN  ...                     NaN
# 162                 NaN  NaN  ...                     NaN
# 163                 NaN  NaN  ...                     NaN
# 164                 NaN  NaN  ...                     NaN
# 165                 NaN  NaN  ...                     NaN
#
#      experimental_post_n  Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  \
# 0                    NaN          NaN          NaN          NaN          NaN
# 1                   17.0          NaN          NaN          NaN          NaN
# 2                    NaN          NaN          NaN          NaN          NaN
# 3                    NaN          NaN          NaN          NaN          NaN
# 4                    NaN          NaN          NaN          NaN          NaN
# ..                   ...          ...          ...          ...          ...
# 161                  NaN          NaN          NaN          NaN          NaN
# 162                  0.0          NaN          NaN          NaN          NaN
# 163                  NaN          NaN          NaN          NaN          NaN
# 164                  NaN          NaN          NaN          NaN          NaN
# 165                  0.0          NaN          NaN          NaN          NaN
#
#      Unnamed: 42  Unnamed: 43    PMID_y                           DOI_y
# 0            NaN          NaN  21671144       10.1007/s00415-011-6128-4
# 1            NaN          NaN       NaN                             NaN
# 2            NaN          NaN  29329932       10.1016/j.brs.2017.12.011
# 3            NaN          NaN  32044029       10.1016/j.brs.2020.01.007
# 4            NaN          NaN  16084813  10.1016/j.biopsych.2005.07.003
# ..           ...          ...       ...                             ...
# 161          NaN          NaN       NaN                             NaN
# 162          NaN          NaN       NaN                             NaN
# 163          NaN          NaN       NaN                             NaN
# 164          NaN          NaN       NaN                             NaN
# 165          NaN          NaN       NaN                             NaN
#
# [166 rows x 46 columns]

# %%
merged_df.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/TMS_studies_influencing_memory/metadata/test.csv', index=False)

# %%
# Merge df1 and df2 on 'study', updating PMID and DOI in df1 with values from df2 where available
df1_updated = pd.merge(df1, df2[['study', 'PMID', 'DOI']], on='study', how='left', suffixes=('', '_new'))
df1_updated['PMID'] = df1_updated['PMID_new'].combine_first(df1_updated['PMID'])
df1_updated['DOI'] = df1_updated['DOI_new'].combine_first(df1_updated['DOI'])
df1_updated = df1_updated.drop(columns=['PMID_new', 'DOI_new'])
df1_updated.to_csv('/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/resources/datasets/TMS_studies_influencing_memory/metadata/Updated_TMS_studies_influencing_memory.csv', index=False)

# %%
import nibabel as nib
import numpy as np
input_file = 'input_file.nii'
output_file = input_file.replace('.nii', '_absval.nii')
img = nib.load(input_file)
data = img.get_fdata()
abs_data = np.abs(data)
abs_img = nib.Nifti1Image(abs_data, img.affine, img.header)
nib.save(abs_img, output_file)
