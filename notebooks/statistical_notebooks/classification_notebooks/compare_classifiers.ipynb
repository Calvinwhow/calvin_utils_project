# %% [markdown]
# Enter directory to save to

# %%
out_dir = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/collaborations/barotono_disease_classification/metadata/dataset_8/hello_i_am_the_comparison_folder'

# %% [markdown]
# Compare Multiple Sets of Predictions
# - requires the probabilities csv predicted from above and the true labels.
# - Each CSV of predicted probabilities should correspond to the same labels.
# - The data should remain the same, while the classifier for each csv changed.
#
# - labels_path = 'path/to/observed_labels.csv' <- generated by logistic_regression_notebook.ipynb
# - pred_paths = 'path/to/predicted_probabilities.csv' <- generated by logistic_regression_notebook.ipynb

# %%
labels_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/collaborations/barotono_disease_classification/metadata/dataset_8/wmap_v7/test_results/observed_labels.csv'
pred_paths = ['/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/collaborations/barotono_disease_classification/metadata/dataset_8/hpc/test_results/predicted_probabilities.csv', 
              '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/collaborations/barotono_disease_classification/metadata/dataset_8/wmap_v7/test_results/predicted_probabilities.csv', ]

# %% [markdown]
# Run it

# %%
from calvin_utils.statistical_utils.compare_classifiers import CompareClassifiers
comparator = CompareClassifiers(labels_path=labels_path, pred_paths=pred_paths, n_bootstraps=1000, seed=42)
comparator.run(out_dir)
# Out:
# /Users/cu135/Software_Local/calvin_utils_project/calvin_utils_project/calvin_utils/statistical_utils/compare_classifiers.py:252: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Confidence Interval Method: Empiric Percentile
# Plots saved to: /Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/collaborations/barotono_disease_classification/metadata/dataset_8/hello_i_am_the_comparison_folder
