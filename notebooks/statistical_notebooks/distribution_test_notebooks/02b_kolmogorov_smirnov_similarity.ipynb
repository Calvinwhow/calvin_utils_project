# %%
# Specify the path to your CSV file containing NIFTI paths
input_csv_path = '/Users/cu135/Partners HealthCare Dropbox/Calvin Howard/studies/ccm_memory/results/notebook_00/master_list_working_v4.csv'
sheet = None #'master_list_proper_subjects' ?

# %%
from calvin_utils.permutation_analysis_utils.statsmodels_palm import CalvinStatsmodelsPalm
# Instantiate the PalmPrepararation class
cal_palm = CalvinStatsmodelsPalm(input_csv_path=input_csv_path, output_dir=None, sheet=sheet)
# Call the process_nifti_paths method
data_df = cal_palm.read_and_display_data()
data_df
# Out:
#              Dataset     Subject  \
# 0     adni_Alzheimer  002uSu0619
# 1     adni_Alzheimer  002uSu0729
# 2     adni_Alzheimer  002uSu0816
# 3     adni_Alzheimer  002uSu0938
# 4     adni_Alzheimer  002uSu0954
# ...              ...         ...
# 2745  nilakantan_tms        12DO
# 2746  nilakantan_tms        13DO
# 2747  nilakantan_tms        14DO
# 2748  nilakantan_tms        15DO
# 2749  nilakantan_tms        16DO
#
#                                           Roi_File_Path  \
# 0     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 1     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 2     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 3     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 4     /Volumes/Expansion/datasets/adni/neuroimaging/...
# ...                                                 ...
# 2745                                                NaN
# 2746                                                NaN
# 2747                                                NaN
# 2748                                                NaN
# 2749                                                NaN
#
#                                         Nifti_File_Path        Age  Sex  \
# 0     /Volumes/Expansion/datasets/adni/neuroimaging/...  77.512329  NaN
# 1     /Volumes/Expansion/datasets/adni/neuroimaging/...  65.224658  NaN
# 2     /Volumes/Expansion/datasets/adni/neuroimaging/...  70.838356    F
# 3     /Volumes/Expansion/datasets/adni/neuroimaging/...  82.276712    F
# 4     /Volumes/Expansion/datasets/adni/neuroimaging/...  69.452055  NaN
# ...                                                 ...        ...  ...
# 2745  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2746  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2747  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2748  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2749  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
#
#       Diagnosis  Baseline_Cognition  Unnamed__8  Unnamed__9  Unnamed__10  \
# 0     Alzheimer               19.33         NaN         NaN          0.0
# 1     Alzheimer                6.67         NaN         NaN        -20.0
# 2     Alzheimer               16.00         NaN         NaN        -20.0
# 3     Alzheimer               21.67         NaN         NaN          0.0
# 4     Alzheimer               10.67         NaN         NaN        -10.0
# ...         ...                 ...         ...         ...          ...
# 2745     Normal                 NaN         NaN         NaN          NaN
# 2746     Normal                 NaN         NaN         NaN          NaN
# 2747     Normal                 NaN         NaN         NaN          NaN
# 2748     Normal                 NaN         NaN         NaN          NaN
# 2749     Normal                 NaN         NaN         NaN          NaN
#
#       Memory_Score  Unnamed__12         Outcome_Measure Cause_of_Change  \
# 0              0.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 1             20.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 2             20.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 3              0.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 4             10.0          NaN  ADAS Cog 11 Question 4         Atrophy
# ...            ...          ...                     ...             ...
# 2745           9.0          NaN                     NaN             NaN
# 2746           3.0          NaN                     NaN             NaN
# 2747          14.0          NaN                     NaN             NaN
# 2748           1.0          NaN                     NaN             NaN
# 2749          20.0          NaN                     NaN             NaN
#
#        Group                Source Localization_Method
# 0     Lesion  Petersen et al. 2010                 MRI
# 1     Lesion  Petersen et al. 2010                 MRI
# 2     Lesion  Petersen et al. 2010                 MRI
# 3     Lesion  Petersen et al. 2010                 MRI
# 4     Lesion  Petersen et al. 2010                 MRI
# ...      ...                   ...                 ...
# 2745     NaN                   NaN                 NaN
# 2746     NaN                   NaN                 NaN
# 2747     NaN                   NaN                 NaN
# 2748     NaN                   NaN                 NaN
# 2749     NaN                   NaN                 NaN
#
# [2750 rows x 18 columns]

# %% [markdown]
# # 01 - Preprocess Your Data

# %% [markdown]
# **Handle NANs**
# - Set drop_nans=True is you would like to remove NaNs from data
# - Provide a column name or a list of column names to remove NaNs from

# %%
data_df.columns
# Out:
# Index(['Dataset', 'Subject', 'Roi_File_Path', 'Nifti_File_Path', 'Age', 'Sex',
#        'Diagnosis', 'Baseline_Cognition', 'Unnamed__8', 'Unnamed__9',
#        'Unnamed__10', 'Memory_Score', 'Unnamed__12', 'Outcome_Measure',
#        'Cause_of_Change', 'Group', 'Source', 'Localization_Method'],
#       dtype='object')

# %%
drop_list = ['Memory_Score', 'Dataset']

# %%
data_df = cal_palm.drop_nans_from_columns(columns_to_drop_from=drop_list)
data_df
# Out:
#              Dataset     Subject  \
# 0     adni_Alzheimer  002uSu0619
# 1     adni_Alzheimer  002uSu0729
# 2     adni_Alzheimer  002uSu0816
# 3     adni_Alzheimer  002uSu0938
# 4     adni_Alzheimer  002uSu0954
# ...              ...         ...
# 2745  nilakantan_tms        12DO
# 2746  nilakantan_tms        13DO
# 2747  nilakantan_tms        14DO
# 2748  nilakantan_tms        15DO
# 2749  nilakantan_tms        16DO
#
#                                           Roi_File_Path  \
# 0     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 1     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 2     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 3     /Volumes/Expansion/datasets/adni/neuroimaging/...
# 4     /Volumes/Expansion/datasets/adni/neuroimaging/...
# ...                                                 ...
# 2745                                                NaN
# 2746                                                NaN
# 2747                                                NaN
# 2748                                                NaN
# 2749                                                NaN
#
#                                         Nifti_File_Path        Age  Sex  \
# 0     /Volumes/Expansion/datasets/adni/neuroimaging/...  77.512329  NaN
# 1     /Volumes/Expansion/datasets/adni/neuroimaging/...  65.224658  NaN
# 2     /Volumes/Expansion/datasets/adni/neuroimaging/...  70.838356    F
# 3     /Volumes/Expansion/datasets/adni/neuroimaging/...  82.276712    F
# 4     /Volumes/Expansion/datasets/adni/neuroimaging/...  69.452055  NaN
# ...                                                 ...        ...  ...
# 2745  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2746  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2747  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2748  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
# 2749  /Volumes/Expansion/datasets/VOSS_STUDIES_TMS/N...        NaN  NaN
#
#       Diagnosis  Baseline_Cognition  Unnamed__8  Unnamed__9  Unnamed__10  \
# 0     Alzheimer               19.33         NaN         NaN          0.0
# 1     Alzheimer                6.67         NaN         NaN        -20.0
# 2     Alzheimer               16.00         NaN         NaN        -20.0
# 3     Alzheimer               21.67         NaN         NaN          0.0
# 4     Alzheimer               10.67         NaN         NaN        -10.0
# ...         ...                 ...         ...         ...          ...
# 2745     Normal                 NaN         NaN         NaN          NaN
# 2746     Normal                 NaN         NaN         NaN          NaN
# 2747     Normal                 NaN         NaN         NaN          NaN
# 2748     Normal                 NaN         NaN         NaN          NaN
# 2749     Normal                 NaN         NaN         NaN          NaN
#
#       Memory_Score  Unnamed__12         Outcome_Measure Cause_of_Change  \
# 0              0.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 1             20.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 2             20.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 3              0.0          NaN  ADAS Cog 11 Question 4         Atrophy
# 4             10.0          NaN  ADAS Cog 11 Question 4         Atrophy
# ...            ...          ...                     ...             ...
# 2745           9.0          NaN                     NaN             NaN
# 2746           3.0          NaN                     NaN             NaN
# 2747          14.0          NaN                     NaN             NaN
# 2748           1.0          NaN                     NaN             NaN
# 2749          20.0          NaN                     NaN             NaN
#
#        Group                Source Localization_Method
# 0     Lesion  Petersen et al. 2010                 MRI
# 1     Lesion  Petersen et al. 2010                 MRI
# 2     Lesion  Petersen et al. 2010                 MRI
# 3     Lesion  Petersen et al. 2010                 MRI
# 4     Lesion  Petersen et al. 2010                 MRI
# ...      ...                   ...                 ...
# 2745     NaN                   NaN                 NaN
# 2746     NaN                   NaN                 NaN
# 2747     NaN                   NaN                 NaN
# 2748     NaN                   NaN                 NaN
# 2749     NaN                   NaN                 NaN
#
# [2342 rows x 18 columns]

# %% [markdown]
# **Drop Row Based on Value of Column**
#
# Define the column, condition, and value for dropping rows
# - column = 'your_column_name'
# - condition = 'above'  # Options: 'equal', 'above', 'below'

# %% [markdown]
# Set the parameters for dropping rows

# %%
data_df['Dataset'].unique()

# %%
data_df.columns

# %%
column = 'Dataset'  # The column you'd like to evaluate
condition = 'equal'  # Thecondition to check ('equal', 'above', 'below', 'not')
value = 'manitoba_memory' # The value to compare against

# %%
data_df, other_df = cal_palm.drop_rows_based_on_value(column, condition, value)
data_df

# %% [markdown]
# Regress out Covariates

# %%
data_df.columns

# %%
dependent_variable_list = ['Memory_Score']
regressors = ['Source', 'Age']

# %%
#Impute covariates in if desired
for col in regressors:
    if data_df[col].dtype == 'O':  # object/categorical
        data_df[col] = data_df[col].fillna(data_df[col].mode()[0])
    else:  # numeric
        data_df[col] = data_df[col].fillna(data_df[col].mean())
data_df[regressors].isna().sum()

# %%
from calvin_utils.statistical_utils.regression_utils import RegressOutCovariates
data_df, adjusted_dep_vars_list = RegressOutCovariates.run(df=data_df, dependent_variable_list=dependent_variable_list, covariates_list=regressors)
print(adjusted_dep_vars_list)

# %% [markdown]
# **Standardize Data**
# - Enter Columns you Don't want to standardize into a list

# %%
data_df.columns
# Out:
# Index(['Dataset', 'Subject', 'Roi_File_Path', 'Nifti_File_Path', 'Age', 'Sex',
#        'Diagnosis', 'Baseline_Cognition', 'Unnamed__8', 'Unnamed__9',
#        'Unnamed__10', 'Memory_Score', 'Unnamed__12', 'Outcome_Measure',
#        'Cause_of_Change', 'Group', 'Source', 'Localization_Method'],
#       dtype='object')

# %%
# Remove anything you don't want to standardize
cols_not_to_standardize = []

# %%
data_df = cal_palm.standardize_columns(cols_not_to_standardize, group_col='Dataset')
# Out:
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Sex.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Sex.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Sex.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Roi_File_Path.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Outcome_Measure.
# Unable to standardize column Cause_of_Change.
# Unable to standardize column Group.
# Unable to standardize column Source.
# Unable to standardize column Localization_Method.
# Unable to standardize column Subject.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Subject.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Subject.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.
# Unable to standardize column Subject.
# Unable to standardize column Nifti_File_Path.
# Unable to standardize column Diagnosis.

# %% [markdown]
# Do Miscellaneous Data Cleaning

# %%
# data_df = data_df[(data_df['Pre_Post_Memory_Effect_Size__Cohen_s_D_'] >= -1) & (data_df['Pre_Post_Memory_Effect_Size__Cohen_s_D_'] <= 1)]

# %% [markdown]
# Test Similarity Across Distributions

# %%
import numpy as np
import pandas as pd
from itertools import combinations
from scipy.stats import ks_2samp
from tqdm import tqdm


class KSSimilarityTester:
    """
    Mean pair-wise Kolmogorov–Smirnov distance across categories + permutation test.

    Parameters
    ----------
    df : pd.DataFrame
    dv : str
        Name of the numeric dependent-variable column.
    cat : str
        Categorical column that defines the cohorts to compare.
    block : str | None, default None
        Optional column whose values define *exchangeability blocks*.
        Permutations are performed **within** each block only.
        (Typical use-case: Age_Group, Site, Batch, etc.)
    n_perms : int, default 1000
    random_state : int | None, default None
    """

    def __init__(
        self,
        df: pd.DataFrame,
        dv: str,
        cat: str,
        block: str | None = None,
        n_perms: int = 1000,
        random_state: int | None = None,
    ):
        cols = [dv, cat] + ([block] if block else [])
        self.df = df[cols].dropna().reset_index(drop=True)

        self.dv = dv
        self.cat = cat
        self.block = block
        self.n_perms = n_perms
        self.rng = np.random.default_rng(random_state)

        self.categories = self.df[cat].unique()
        self.obs_avg_ks: float | None = None
        self.perm_avgs: np.ndarray | None = None
        self.sim_p: float | None = None
        self.dissim_p: float | None = None

    # Internal #
    def _pairwise_mean_ks(self, labels: np.ndarray) -> float:
        """Mean KS statistic over all category pairs for the given label vector."""
        groups = {c: self.df[self.dv].values[labels == c] for c in self.categories}
        ks_vals = [
            ks_2samp(groups[a], groups[b], method="asymp").statistic
            for a, b in combinations(self.categories, 2)
        ]
        return float(np.mean(ks_vals))

    def _permute_labels(self) -> np.ndarray:
        """
        Return a permutation of cohort labels.
        • If no block column → shuffle all labels.
        • If block column present → shuffle labels **within** each block.
        """
        labels = self.df[self.cat].values.copy()

        if self.block is None:
            return self.rng.permutation(labels)

        # stratified permutation
        block_vals = self.df[self.block].values
        for b in np.unique(block_vals):
            idx = np.where(block_vals == b)[0]
            labels[idx] = self.rng.permutation(labels[idx])
        return labels

    # Public #
    def run(self) -> dict:
        """Compute observed statistic, permutation null, and p-values."""
        original_labels = self.df[self.cat].values
        self.obs_avg_ks = self._pairwise_mean_ks(original_labels)

        self.perm_avgs = np.empty(self.n_perms, dtype=float)
        for i in tqdm(range(self.n_perms), desc="Permuting", leave=False):
            permuted = self._permute_labels()
            self.perm_avgs[i] = self._pairwise_mean_ks(permuted)

        self.sim_p = (self.perm_avgs <= self.obs_avg_ks).mean()
        self.dissim_p = (self.perm_avgs >= self.obs_avg_ks).mean()

        return {
            "observed_mean_ks": self.obs_avg_ks,
            "permuted_mean_ks": self.perm_avgs,
            "similarity_p": self.sim_p,
            "dissimilarity_p": self.dissim_p,
        }

    def report(self) -> None:
        if self.obs_avg_ks is None:
            raise RuntimeError("Call .run() first.")
        print(f"Observed mean KS        : {self.obs_avg_ks:.4f}")
        print(f"Mean permuted KS        : {self.perm_avgs.mean():.4f}")
        print(f"Similarity p-value      : {self.sim_p:.4g}")
        print(f"Dissimilarity p-value   : {self.dissim_p:.4g}")

# %%
data_df.columns
# Out:
# Index(['Dataset', 'Subject', 'Roi_File_Path', 'Nifti_File_Path', 'Age', 'Sex',
#        'Diagnosis', 'Baseline_Cognition', 'Unnamed__8', 'Unnamed__9',
#        'Unnamed__10', 'Memory_Score', 'Unnamed__12', 'Outcome_Measure',
#        'Cause_of_Change', 'Group', 'Source', 'Localization_Method'],
#       dtype='object')

# %%
data_df['Cause_of_Change'].unique()
# Out:
# array(['Atrophy', 'Acute Stroke', 'Fornix', 'Penetrating TBI',
#        'Parietal Lobe', 'iEEG Stimulation', 'Anterior Thalamic Nucleus',
#        'Focal Hypometabolism', 'Focal Plaque', 'Subthalamic Nucleus', nan],
#       dtype=object)

# %%
tester = KSSimilarityTester(
    data_df,
    dv='Memory_Score',
    cat="Cause_of_Change",
    block="Group",
    n_perms=1000,
    random_state=42,
)
result = tester.run()
tester.report()
# Out:
# Observed mean KS        : 0.2428
# Mean permuted KS        : 0.1496
# Similarity p-value      : 1
# Dissimilarity p-value   : 0
