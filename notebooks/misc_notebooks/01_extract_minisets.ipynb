# %%
#!/usr/bin/env python3

import os
import shutil
import json
import csv
from glob import glob
import gzip
import shutil as sh

# Variables
ORIG_DIR = "/Volumes/Seagate Por/FUSBIDS/derivatives/leaddbs"
DEST_DIR = "/Volumes/HowExp/datasets/07b_BWH_EssentialTremor_HIFUS/data"
JSON_LOC = "/Volumes/Seagate Por/FUSBIDS/dataset_description.json"

FOLDERS_TO_EXTRACT = ["miscellaneous"]
FILES_TO_EXTRACT = {
    "preprocessing/anat/*T1w*": "ses-pre/anat/T1",
    "coregistration/anat/sub-*-postop_space-anchorNative_desc-preproc_acq-sag_MRI": "ses-post/anat/T1",
}
# Ensure destination directory exists
os.makedirs(DEST_DIR, exist_ok=True)

# with open(JSON_LOC, 'r') as f:
#     participants_list = json.load(f)
#     participants = {participant['id']: participant for participant in participants_list if 'id' in participant}

# # Fast metadata retrieval
# def find_metadata(sub_id):
#     return participants.get(sub_id)


# Process each subfolder
for subfolder in os.listdir(ORIG_DIR):
    subfolder_path = os.path.join(ORIG_DIR, subfolder)
    # metadata = find_metadata(subfolder)
    subfolder_dest = os.path.join(DEST_DIR, subfolder)
    print(subfolder_dest)
    if os.path.exists(subfolder_dest):
        
        continue
    print(subfolder)
    
    
    # if metadata is None:
    #     print(f"No metadata found for {subfolder}, skipping.")
    #     continue

    city = 'BWH'
    condition = 'EssentialTremor'
    subject = subfolder
    
    # if subject[0] == ".":
    #     print(f"Hidden folder: {subject}. Skipping")
    #     continue
    
    # city = metadata.get('City', 'misc')
    # condition = metadata.get('Condition', 'unknown')
    # subject = metadata['id']

    subdir = f"{city}_{condition}_DBS"
    # dataset_dir = os.path.join(DEST_DIR, subdir)

    # # if os.path.exists(os.path.join(dataset_dir, 'data', subject)):
    # #     print(f"Subject directory {subject} already exists. Skipping...")
    # #     continue
    # os.makedirs(os.path.join(dataset_dir, "data"), exist_ok=True)
    # os.makedirs(os.path.join(dataset_dir, "metadata"), exist_ok=True)
    
    # # Write metadata to master CSV
    # metadata_file = os.path.join(dataset_dir, "metadata", "master_list.csv")
    # file_exists = os.path.isfile(metadata_file)
    # with open(metadata_file, 'a', newline='') as csvfile:
    #     writer = csv.writer(csvfile)
    #     if not file_exists:
    #         writer.writerow(["ID", "Age", "ElModel", "Condition", "YearsSinceDx", "Target", "DOIs"])
    #     writer.writerow([
    #         subject,
    #         'unknown',
    #         'hifus',
    #         condition,
    #         'NA',
    #         'VIM',
    #         '10.1126/sciadv.adp0532'
    #     ])

    # Copy required folders/files
    # for d in FOLDERS_TO_EXTRACT:
    #     full_pattern = os.path.join(subfolder_path, d)
    #     dst_folder = os.path.join(DEST_DIR, "data", subject, 'ses-pre', d)
    #     if os.path.exists(dst_folder):
    #         print(f"Folder {dst_folder} already exists. Skipping...")
    #         continue
    #     os.makedirs(dst_folder, exist_ok=True)
    #     if os.path.isdir(full_pattern):
    #         shutil.copytree(full_pattern, dst_folder, dirs_exist_ok=True)
        
    # for key, value in FILES_TO_EXTRACT.items():
    #     full_pattern = os.path.join(subfolder_path, key)
    #     dst_file = os.path.join(DEST_DIR, "data", subject, value)
    #     found_files = glob(full_pattern)
    #     os.makedirs(os.path.dirname(dst_file), exist_ok=True)
    #     for i, f in enumerate(found_files):
    #         # Compress the .nii file to .nii.gz
    #         suffix = "" if i == 0 else f"_{i}"
    #         with open(f, 'rb') as f_in, gzip.open(dst_file + f"{suffix}.nii.gz", 'wb') as f_out:
    #             sh.copyfileobj(f_in, f_out)
    print(f"Processed subject: {subfolder}")
# Out:
# /Volumes/HowExp/datasets/HIFUS_minisets/logs
# logs
# Processed subject: logs
# /Volumes/HowExp/datasets/HIFUS_minisets/._logs
# ._logs
# Processed subject: ._logs
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap1
# sub-Redcap1
# Processed subject: sub-Redcap1
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap1
# ._sub-Redcap1
# Processed subject: ._sub-Redcap1
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap10
# sub-Redcap10
# Processed subject: sub-Redcap10
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap10
# ._sub-Redcap10
# Processed subject: ._sub-Redcap10
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap100
# sub-Redcap100
# Processed subject: sub-Redcap100
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap100
# ._sub-Redcap100
# Processed subject: ._sub-Redcap100
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap101
# sub-Redcap101
# Processed subject: sub-Redcap101
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap101
# ._sub-Redcap101
# Processed subject: ._sub-Redcap101
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap102
# sub-Redcap102
# Processed subject: sub-Redcap102
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap102
# ._sub-Redcap102
# Processed subject: ._sub-Redcap102
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap103
# sub-Redcap103
# Processed subject: sub-Redcap103
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap103
# ._sub-Redcap103
# Processed subject: ._sub-Redcap103
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap104
# sub-Redcap104
# Processed subject: sub-Redcap104
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap104
# ._sub-Redcap104
# Processed subject: ._sub-Redcap104
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap105
# sub-Redcap105
# Processed subject: sub-Redcap105
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap105
# ._sub-Redcap105
# Processed subject: ._sub-Redcap105
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap106
# sub-Redcap106
# Processed subject: sub-Redcap106
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap106
# ._sub-Redcap106
# Processed subject: ._sub-Redcap106
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap107
# sub-Redcap107
# Processed subject: sub-Redcap107
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap107
# ._sub-Redcap107
# Processed subject: ._sub-Redcap107
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap108
# sub-Redcap108
# Processed subject: sub-Redcap108
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap108
# ._sub-Redcap108
# Processed subject: ._sub-Redcap108
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap109
# sub-Redcap109
# Processed subject: sub-Redcap109
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap109
# ._sub-Redcap109
# Processed subject: ._sub-Redcap109
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap11
# sub-Redcap11
# Processed subject: sub-Redcap11
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap11
# ._sub-Redcap11
# Processed subject: ._sub-Redcap11
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap110
# sub-Redcap110
# Processed subject: sub-Redcap110
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap110
# ._sub-Redcap110
# Processed subject: ._sub-Redcap110
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap111
# sub-Redcap111
# Processed subject: sub-Redcap111
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap111
# ._sub-Redcap111
# Processed subject: ._sub-Redcap111
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap112
# sub-Redcap112
# Processed subject: sub-Redcap112
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap112
# ._sub-Redcap112
# Processed subject: ._sub-Redcap112
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap113
# sub-Redcap113
# Processed subject: sub-Redcap113
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap113
# ._sub-Redcap113
# Processed subject: ._sub-Redcap113
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap114
# sub-Redcap114
# Processed subject: sub-Redcap114
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap114
# ._sub-Redcap114
# Processed subject: ._sub-Redcap114
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap115
# sub-Redcap115
# Processed subject: sub-Redcap115
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap115
# ._sub-Redcap115
# Processed subject: ._sub-Redcap115
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap116
# sub-Redcap116
# Processed subject: sub-Redcap116
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap116
# ._sub-Redcap116
# Processed subject: ._sub-Redcap116
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap117
# sub-Redcap117
# Processed subject: sub-Redcap117
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap117
# ._sub-Redcap117
# Processed subject: ._sub-Redcap117
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap118
# sub-Redcap118
# Processed subject: sub-Redcap118
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap118
# ._sub-Redcap118
# Processed subject: ._sub-Redcap118
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap119
# sub-Redcap119
# Processed subject: sub-Redcap119
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap119
# ._sub-Redcap119
# Processed subject: ._sub-Redcap119
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap12
# sub-Redcap12
# Processed subject: sub-Redcap12
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap12
# ._sub-Redcap12
# Processed subject: ._sub-Redcap12
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap120
# sub-Redcap120
# Processed subject: sub-Redcap120
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap120
# ._sub-Redcap120
# Processed subject: ._sub-Redcap120
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap121
# sub-Redcap121
# Processed subject: sub-Redcap121
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap121
# ._sub-Redcap121
# Processed subject: ._sub-Redcap121
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap122
# sub-Redcap122
# Processed subject: sub-Redcap122
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap122
# ._sub-Redcap122
# Processed subject: ._sub-Redcap122
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap123
# sub-Redcap123
# Processed subject: sub-Redcap123
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap123
# ._sub-Redcap123
# Processed subject: ._sub-Redcap123
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap124
# sub-Redcap124
# Processed subject: sub-Redcap124
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap124
# ._sub-Redcap124
# Processed subject: ._sub-Redcap124
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap125
# sub-Redcap125
# Processed subject: sub-Redcap125
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap125
# ._sub-Redcap125
# Processed subject: ._sub-Redcap125
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap126
# sub-Redcap126
# Processed subject: sub-Redcap126
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap126
# ._sub-Redcap126
# Processed subject: ._sub-Redcap126
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap127
# sub-Redcap127
# Processed subject: sub-Redcap127
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap127
# ._sub-Redcap127
# Processed subject: ._sub-Redcap127
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap128
# sub-Redcap128
# Processed subject: sub-Redcap128
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap128
# ._sub-Redcap128
# Processed subject: ._sub-Redcap128
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap129
# sub-Redcap129
# Processed subject: sub-Redcap129
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap129
# ._sub-Redcap129
# Processed subject: ._sub-Redcap129
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap13
# sub-Redcap13
# Processed subject: sub-Redcap13
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap13
# ._sub-Redcap13
# Processed subject: ._sub-Redcap13
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap130
# sub-Redcap130
# Processed subject: sub-Redcap130
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap130
# ._sub-Redcap130
# Processed subject: ._sub-Redcap130
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap131
# sub-Redcap131
# Processed subject: sub-Redcap131
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap131
# ._sub-Redcap131
# Processed subject: ._sub-Redcap131
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap132
# sub-Redcap132
# Processed subject: sub-Redcap132
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap132
# ._sub-Redcap132
# Processed subject: ._sub-Redcap132
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap133
# sub-Redcap133
# Processed subject: sub-Redcap133
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap133
# ._sub-Redcap133
# Processed subject: ._sub-Redcap133
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap134
# sub-Redcap134
# Processed subject: sub-Redcap134
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap134
# ._sub-Redcap134
# Processed subject: ._sub-Redcap134
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap135
# sub-Redcap135
# Processed subject: sub-Redcap135
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap135
# ._sub-Redcap135
# Processed subject: ._sub-Redcap135
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap136
# sub-Redcap136
# Processed subject: sub-Redcap136
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap136
# ._sub-Redcap136
# Processed subject: ._sub-Redcap136
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap137
# sub-Redcap137
# Processed subject: sub-Redcap137
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap137
# ._sub-Redcap137
# Processed subject: ._sub-Redcap137
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap138
# sub-Redcap138
# Processed subject: sub-Redcap138
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap138
# ._sub-Redcap138
# Processed subject: ._sub-Redcap138
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap14
# sub-Redcap14
# Processed subject: sub-Redcap14
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap14
# ._sub-Redcap14
# Processed subject: ._sub-Redcap14
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap140
# sub-Redcap140
# Processed subject: sub-Redcap140
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap140
# ._sub-Redcap140
# Processed subject: ._sub-Redcap140
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap141
# sub-Redcap141
# Processed subject: sub-Redcap141
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap141
# ._sub-Redcap141
# Processed subject: ._sub-Redcap141
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap142
# sub-Redcap142
# Processed subject: sub-Redcap142
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap142
# ._sub-Redcap142
# Processed subject: ._sub-Redcap142
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap143
# sub-Redcap143
# Processed subject: sub-Redcap143
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap143
# ._sub-Redcap143
# Processed subject: ._sub-Redcap143
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap144
# sub-Redcap144
# Processed subject: sub-Redcap144
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap144
# ._sub-Redcap144
# Processed subject: ._sub-Redcap144
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap145
# sub-Redcap145
# Processed subject: sub-Redcap145
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap145
# ._sub-Redcap145
# Processed subject: ._sub-Redcap145
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap146
# sub-Redcap146
# Processed subject: sub-Redcap146
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap146
# ._sub-Redcap146
# Processed subject: ._sub-Redcap146
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap147
# sub-Redcap147
# Processed subject: sub-Redcap147
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap147
# ._sub-Redcap147
# Processed subject: ._sub-Redcap147
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap148
# sub-Redcap148
# Processed subject: sub-Redcap148
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap148
# ._sub-Redcap148
# Processed subject: ._sub-Redcap148
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap149
# sub-Redcap149
# Processed subject: sub-Redcap149
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap149
# ._sub-Redcap149
# Processed subject: ._sub-Redcap149
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap15
# sub-Redcap15
# Processed subject: sub-Redcap15
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap15
# ._sub-Redcap15
# Processed subject: ._sub-Redcap15
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap150
# sub-Redcap150
# Processed subject: sub-Redcap150
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap150
# ._sub-Redcap150
# Processed subject: ._sub-Redcap150
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap151
# sub-Redcap151
# Processed subject: sub-Redcap151
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap151
# ._sub-Redcap151
# Processed subject: ._sub-Redcap151
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap152
# sub-Redcap152
# Processed subject: sub-Redcap152
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap152
# ._sub-Redcap152
# Processed subject: ._sub-Redcap152
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap153
# sub-Redcap153
# Processed subject: sub-Redcap153
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap153
# ._sub-Redcap153
# Processed subject: ._sub-Redcap153
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap154
# sub-Redcap154
# Processed subject: sub-Redcap154
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap154
# ._sub-Redcap154
# Processed subject: ._sub-Redcap154
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap155
# sub-Redcap155
# Processed subject: sub-Redcap155
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap155
# ._sub-Redcap155
# Processed subject: ._sub-Redcap155
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap156
# sub-Redcap156
# Processed subject: sub-Redcap156
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap156
# ._sub-Redcap156
# Processed subject: ._sub-Redcap156
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap157
# sub-Redcap157
# Processed subject: sub-Redcap157
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap157
# ._sub-Redcap157
# Processed subject: ._sub-Redcap157
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap158
# sub-Redcap158
# Processed subject: sub-Redcap158
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap158
# ._sub-Redcap158
# Processed subject: ._sub-Redcap158
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap159
# sub-Redcap159
# Processed subject: sub-Redcap159
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap159
# ._sub-Redcap159
# Processed subject: ._sub-Redcap159
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap16
# sub-Redcap16
# Processed subject: sub-Redcap16
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap16
# ._sub-Redcap16
# Processed subject: ._sub-Redcap16
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap160
# sub-Redcap160
# Processed subject: sub-Redcap160
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap160
# ._sub-Redcap160
# Processed subject: ._sub-Redcap160
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap161
# sub-Redcap161
# Processed subject: sub-Redcap161
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap161
# ._sub-Redcap161
# Processed subject: ._sub-Redcap161
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap162
# sub-Redcap162
# Processed subject: sub-Redcap162
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap162
# ._sub-Redcap162
# Processed subject: ._sub-Redcap162
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap163
# sub-Redcap163
# Processed subject: sub-Redcap163
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap163
# ._sub-Redcap163
# Processed subject: ._sub-Redcap163
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap164
# sub-Redcap164
# Processed subject: sub-Redcap164
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap164
# ._sub-Redcap164
# Processed subject: ._sub-Redcap164
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap165
# sub-Redcap165
# Processed subject: sub-Redcap165
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap165
# ._sub-Redcap165
# Processed subject: ._sub-Redcap165
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap166
# sub-Redcap166
# Processed subject: sub-Redcap166
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap166
# ._sub-Redcap166
# Processed subject: ._sub-Redcap166
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap167
# sub-Redcap167
# Processed subject: sub-Redcap167
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap167
# ._sub-Redcap167
# Processed subject: ._sub-Redcap167
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap168
# sub-Redcap168
# Processed subject: sub-Redcap168
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap168
# ._sub-Redcap168
# Processed subject: ._sub-Redcap168
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap169
# sub-Redcap169
# Processed subject: sub-Redcap169
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap169
# ._sub-Redcap169
# Processed subject: ._sub-Redcap169
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap17
# sub-Redcap17
# Processed subject: sub-Redcap17
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap17
# ._sub-Redcap17
# Processed subject: ._sub-Redcap17
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap170
# sub-Redcap170
# Processed subject: sub-Redcap170
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap170
# ._sub-Redcap170
# Processed subject: ._sub-Redcap170
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap171
# sub-Redcap171
# Processed subject: sub-Redcap171
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap171
# ._sub-Redcap171
# Processed subject: ._sub-Redcap171
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap172
# sub-Redcap172
# Processed subject: sub-Redcap172
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap172
# ._sub-Redcap172
# Processed subject: ._sub-Redcap172
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap173
# sub-Redcap173
# Processed subject: sub-Redcap173
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap173
# ._sub-Redcap173
# Processed subject: ._sub-Redcap173
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap174
# sub-Redcap174
# Processed subject: sub-Redcap174
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap174
# ._sub-Redcap174
# Processed subject: ._sub-Redcap174
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap175
# sub-Redcap175
# Processed subject: sub-Redcap175
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap175
# ._sub-Redcap175
# Processed subject: ._sub-Redcap175
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap176
# sub-Redcap176
# Processed subject: sub-Redcap176
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap176
# ._sub-Redcap176
# Processed subject: ._sub-Redcap176
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap177
# sub-Redcap177
# Processed subject: sub-Redcap177
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap177
# ._sub-Redcap177
# Processed subject: ._sub-Redcap177
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap178
# sub-Redcap178
# Processed subject: sub-Redcap178
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap178
# ._sub-Redcap178
# Processed subject: ._sub-Redcap178
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap179
# sub-Redcap179
# Processed subject: sub-Redcap179
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap179
# ._sub-Redcap179
# Processed subject: ._sub-Redcap179
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap18
# sub-Redcap18
# Processed subject: sub-Redcap18
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap18
# ._sub-Redcap18
# Processed subject: ._sub-Redcap18
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap180
# sub-Redcap180
# Processed subject: sub-Redcap180
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap180
# ._sub-Redcap180
# Processed subject: ._sub-Redcap180
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap181
# sub-Redcap181
# Processed subject: sub-Redcap181
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap181
# ._sub-Redcap181
# Processed subject: ._sub-Redcap181
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap182
# sub-Redcap182
# Processed subject: sub-Redcap182
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap182
# ._sub-Redcap182
# Processed subject: ._sub-Redcap182
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap183
# sub-Redcap183
# Processed subject: sub-Redcap183
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap183
# ._sub-Redcap183
# Processed subject: ._sub-Redcap183
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap184
# sub-Redcap184
# Processed subject: sub-Redcap184
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap184
# ._sub-Redcap184
# Processed subject: ._sub-Redcap184
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap185
# sub-Redcap185
# Processed subject: sub-Redcap185
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap185
# ._sub-Redcap185
# Processed subject: ._sub-Redcap185
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap186
# sub-Redcap186
# Processed subject: sub-Redcap186
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap186
# ._sub-Redcap186
# Processed subject: ._sub-Redcap186
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap187
# sub-Redcap187
# Processed subject: sub-Redcap187
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap187
# ._sub-Redcap187
# Processed subject: ._sub-Redcap187
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap188
# sub-Redcap188
# Processed subject: sub-Redcap188
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap188
# ._sub-Redcap188
# Processed subject: ._sub-Redcap188
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap189
# sub-Redcap189
# Processed subject: sub-Redcap189
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap189
# ._sub-Redcap189
# Processed subject: ._sub-Redcap189
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap19
# sub-Redcap19
# Processed subject: sub-Redcap19
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap19
# ._sub-Redcap19
# Processed subject: ._sub-Redcap19
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap190
# sub-Redcap190
# Processed subject: sub-Redcap190
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap190
# ._sub-Redcap190
# Processed subject: ._sub-Redcap190
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap191
# sub-Redcap191
# Processed subject: sub-Redcap191
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap191
# ._sub-Redcap191
# Processed subject: ._sub-Redcap191
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap192
# sub-Redcap192
# Processed subject: sub-Redcap192
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap192
# ._sub-Redcap192
# Processed subject: ._sub-Redcap192
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap193
# sub-Redcap193
# Processed subject: sub-Redcap193
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap193
# ._sub-Redcap193
# Processed subject: ._sub-Redcap193
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap194
# sub-Redcap194
# Processed subject: sub-Redcap194
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap194
# ._sub-Redcap194
# Processed subject: ._sub-Redcap194
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap195
# sub-Redcap195
# Processed subject: sub-Redcap195
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap195
# ._sub-Redcap195
# Processed subject: ._sub-Redcap195
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap196
# sub-Redcap196
# Processed subject: sub-Redcap196
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap196
# ._sub-Redcap196
# Processed subject: ._sub-Redcap196
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap197
# sub-Redcap197
# Processed subject: sub-Redcap197
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap197
# ._sub-Redcap197
# Processed subject: ._sub-Redcap197
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap198
# sub-Redcap198
# Processed subject: sub-Redcap198
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap198
# ._sub-Redcap198
# Processed subject: ._sub-Redcap198
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap199
# sub-Redcap199
# Processed subject: sub-Redcap199
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap199
# ._sub-Redcap199
# Processed subject: ._sub-Redcap199
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap2
# sub-Redcap2
# Processed subject: sub-Redcap2
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap2
# ._sub-Redcap2
# Processed subject: ._sub-Redcap2
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap20
# sub-Redcap20
# Processed subject: sub-Redcap20
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap20
# ._sub-Redcap20
# Processed subject: ._sub-Redcap20
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap200
# sub-Redcap200
# Processed subject: sub-Redcap200
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap200
# ._sub-Redcap200
# Processed subject: ._sub-Redcap200
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap201
# sub-Redcap201
# Processed subject: sub-Redcap201
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap201
# ._sub-Redcap201
# Processed subject: ._sub-Redcap201
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap202
# sub-Redcap202
# Processed subject: sub-Redcap202
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap202
# ._sub-Redcap202
# Processed subject: ._sub-Redcap202
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap203
# sub-Redcap203
# Processed subject: sub-Redcap203
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap203
# ._sub-Redcap203
# Processed subject: ._sub-Redcap203
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap205
# sub-Redcap205
# Processed subject: sub-Redcap205
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap205
# ._sub-Redcap205
# Processed subject: ._sub-Redcap205
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap206
# sub-Redcap206
# Processed subject: sub-Redcap206
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap206
# ._sub-Redcap206
# Processed subject: ._sub-Redcap206
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap207
# sub-Redcap207
# Processed subject: sub-Redcap207
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap207
# ._sub-Redcap207
# Processed subject: ._sub-Redcap207
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap208
# sub-Redcap208
# Processed subject: sub-Redcap208
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap208
# ._sub-Redcap208
# Processed subject: ._sub-Redcap208
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap209
# sub-Redcap209
# Processed subject: sub-Redcap209
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap209
# ._sub-Redcap209
# Processed subject: ._sub-Redcap209
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap21
# sub-Redcap21
# Processed subject: sub-Redcap21
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap21
# ._sub-Redcap21
# Processed subject: ._sub-Redcap21
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap211
# sub-Redcap211
# Processed subject: sub-Redcap211
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap211
# ._sub-Redcap211
# Processed subject: ._sub-Redcap211
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap212
# sub-Redcap212
# Processed subject: sub-Redcap212
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap212
# ._sub-Redcap212
# Processed subject: ._sub-Redcap212
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap214
# sub-Redcap214
# Processed subject: sub-Redcap214
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap214
# ._sub-Redcap214
# Processed subject: ._sub-Redcap214
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap215
# sub-Redcap215
# Processed subject: sub-Redcap215
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap215
# ._sub-Redcap215
# Processed subject: ._sub-Redcap215
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap216
# sub-Redcap216
# Processed subject: sub-Redcap216
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap216
# ._sub-Redcap216
# Processed subject: ._sub-Redcap216
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap217
# sub-Redcap217
# Processed subject: sub-Redcap217
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap217
# ._sub-Redcap217
# Processed subject: ._sub-Redcap217
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap218
# sub-Redcap218
# Processed subject: sub-Redcap218
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap218
# ._sub-Redcap218
# Processed subject: ._sub-Redcap218
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap22
# sub-Redcap22
# Processed subject: sub-Redcap22
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap22
# ._sub-Redcap22
# Processed subject: ._sub-Redcap22
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap220
# sub-Redcap220
# Processed subject: sub-Redcap220
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap220
# ._sub-Redcap220
# Processed subject: ._sub-Redcap220
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap221
# sub-Redcap221
# Processed subject: sub-Redcap221
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap221
# ._sub-Redcap221
# Processed subject: ._sub-Redcap221
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap222
# sub-Redcap222
# Processed subject: sub-Redcap222
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap222
# ._sub-Redcap222
# Processed subject: ._sub-Redcap222
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap223
# sub-Redcap223
# Processed subject: sub-Redcap223
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap223
# ._sub-Redcap223
# Processed subject: ._sub-Redcap223
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap224
# sub-Redcap224
# Processed subject: sub-Redcap224
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap224
# ._sub-Redcap224
# Processed subject: ._sub-Redcap224
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap225
# sub-Redcap225
# Processed subject: sub-Redcap225
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap225
# ._sub-Redcap225
# Processed subject: ._sub-Redcap225
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap226
# sub-Redcap226
# Processed subject: sub-Redcap226
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap226
# ._sub-Redcap226
# Processed subject: ._sub-Redcap226
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap227
# sub-Redcap227
# Processed subject: sub-Redcap227
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap227
# ._sub-Redcap227
# Processed subject: ._sub-Redcap227
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap228
# sub-Redcap228
# Processed subject: sub-Redcap228
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap228
# ._sub-Redcap228
# Processed subject: ._sub-Redcap228
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap229
# sub-Redcap229
# Processed subject: sub-Redcap229
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap229
# ._sub-Redcap229
# Processed subject: ._sub-Redcap229
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap23
# sub-Redcap23
# Processed subject: sub-Redcap23
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap23
# ._sub-Redcap23
# Processed subject: ._sub-Redcap23
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap230
# sub-Redcap230
# Processed subject: sub-Redcap230
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap230
# ._sub-Redcap230
# Processed subject: ._sub-Redcap230
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap231
# sub-Redcap231
# Processed subject: sub-Redcap231
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap231
# ._sub-Redcap231
# Processed subject: ._sub-Redcap231
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap233
# sub-Redcap233
# Processed subject: sub-Redcap233
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap233
# ._sub-Redcap233
# Processed subject: ._sub-Redcap233
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap234
# sub-Redcap234
# Processed subject: sub-Redcap234
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap234
# ._sub-Redcap234
# Processed subject: ._sub-Redcap234
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap235
# sub-Redcap235
# Processed subject: sub-Redcap235
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap235
# ._sub-Redcap235
# Processed subject: ._sub-Redcap235
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap236
# sub-Redcap236
# Processed subject: sub-Redcap236
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap236
# ._sub-Redcap236
# Processed subject: ._sub-Redcap236
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap238
# sub-Redcap238
# Processed subject: sub-Redcap238
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap238
# ._sub-Redcap238
# Processed subject: ._sub-Redcap238
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap239
# sub-Redcap239
# Processed subject: sub-Redcap239
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap239
# ._sub-Redcap239
# Processed subject: ._sub-Redcap239
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap24
# sub-Redcap24
# Processed subject: sub-Redcap24
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap24
# ._sub-Redcap24
# Processed subject: ._sub-Redcap24
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap246
# sub-Redcap246
# Processed subject: sub-Redcap246
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap246
# ._sub-Redcap246
# Processed subject: ._sub-Redcap246
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap247
# sub-Redcap247
# Processed subject: sub-Redcap247
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap247
# ._sub-Redcap247
# Processed subject: ._sub-Redcap247
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap248
# sub-Redcap248
# Processed subject: sub-Redcap248
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap248
# ._sub-Redcap248
# Processed subject: ._sub-Redcap248
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap249
# sub-Redcap249
# Processed subject: sub-Redcap249
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap249
# ._sub-Redcap249
# Processed subject: ._sub-Redcap249
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap25
# sub-Redcap25
# Processed subject: sub-Redcap25
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap25
# ._sub-Redcap25
# Processed subject: ._sub-Redcap25
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap251
# sub-Redcap251
# Processed subject: sub-Redcap251
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap251
# ._sub-Redcap251
# Processed subject: ._sub-Redcap251
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap252
# sub-Redcap252
# Processed subject: sub-Redcap252
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap252
# ._sub-Redcap252
# Processed subject: ._sub-Redcap252
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap253
# sub-Redcap253
# Processed subject: sub-Redcap253
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap253
# ._sub-Redcap253
# Processed subject: ._sub-Redcap253
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap255
# sub-Redcap255
# Processed subject: sub-Redcap255
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap255
# ._sub-Redcap255
# Processed subject: ._sub-Redcap255
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap256
# sub-Redcap256
# Processed subject: sub-Redcap256
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap256
# ._sub-Redcap256
# Processed subject: ._sub-Redcap256
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap26
# sub-Redcap26
# Processed subject: sub-Redcap26
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap26
# ._sub-Redcap26
# Processed subject: ._sub-Redcap26
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap260
# sub-Redcap260
# Processed subject: sub-Redcap260
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap260
# ._sub-Redcap260
# Processed subject: ._sub-Redcap260
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap262
# sub-Redcap262
# Processed subject: sub-Redcap262
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap262
# ._sub-Redcap262
# Processed subject: ._sub-Redcap262
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap264
# sub-Redcap264
# Processed subject: sub-Redcap264
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap264
# ._sub-Redcap264
# Processed subject: ._sub-Redcap264
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap267
# sub-Redcap267
# Processed subject: sub-Redcap267
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap267
# ._sub-Redcap267
# Processed subject: ._sub-Redcap267
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap268
# sub-Redcap268
# Processed subject: sub-Redcap268
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap268
# ._sub-Redcap268
# Processed subject: ._sub-Redcap268
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap27
# sub-Redcap27
# Processed subject: sub-Redcap27
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap27
# ._sub-Redcap27
# Processed subject: ._sub-Redcap27
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap271
# sub-Redcap271
# Processed subject: sub-Redcap271
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap271
# ._sub-Redcap271
# Processed subject: ._sub-Redcap271
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap273
# sub-Redcap273
# Processed subject: sub-Redcap273
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap273
# ._sub-Redcap273
# Processed subject: ._sub-Redcap273
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap274
# sub-Redcap274
# Processed subject: sub-Redcap274
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap274
# ._sub-Redcap274
# Processed subject: ._sub-Redcap274
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap275
# sub-Redcap275
# Processed subject: sub-Redcap275
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap275
# ._sub-Redcap275
# Processed subject: ._sub-Redcap275
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap277
# sub-Redcap277
# Processed subject: sub-Redcap277
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap277
# ._sub-Redcap277
# Processed subject: ._sub-Redcap277
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap278
# sub-Redcap278
# Processed subject: sub-Redcap278
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap278
# ._sub-Redcap278
# Processed subject: ._sub-Redcap278
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap279
# sub-Redcap279
# Processed subject: sub-Redcap279
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap279
# ._sub-Redcap279
# Processed subject: ._sub-Redcap279
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap28
# sub-Redcap28
# Processed subject: sub-Redcap28
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap28
# ._sub-Redcap28
# Processed subject: ._sub-Redcap28
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap280
# sub-Redcap280
# Processed subject: sub-Redcap280
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap280
# ._sub-Redcap280
# Processed subject: ._sub-Redcap280
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap282
# sub-Redcap282
# Processed subject: sub-Redcap282
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap282
# ._sub-Redcap282
# Processed subject: ._sub-Redcap282
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap283
# sub-Redcap283
# Processed subject: sub-Redcap283
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap283
# ._sub-Redcap283
# Processed subject: ._sub-Redcap283
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap289
# sub-Redcap289
# Processed subject: sub-Redcap289
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap289
# ._sub-Redcap289
# Processed subject: ._sub-Redcap289
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap29
# sub-Redcap29
# Processed subject: sub-Redcap29
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap29
# ._sub-Redcap29
# Processed subject: ._sub-Redcap29
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap295
# sub-Redcap295
# Processed subject: sub-Redcap295
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap295
# ._sub-Redcap295
# Processed subject: ._sub-Redcap295
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap296
# sub-Redcap296
# Processed subject: sub-Redcap296
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap296
# ._sub-Redcap296
# Processed subject: ._sub-Redcap296
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap297
# sub-Redcap297
# Processed subject: sub-Redcap297
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap297
# ._sub-Redcap297
# Processed subject: ._sub-Redcap297
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap298
# sub-Redcap298
# Processed subject: sub-Redcap298
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap298
# ._sub-Redcap298
# Processed subject: ._sub-Redcap298
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap299
# sub-Redcap299
# Processed subject: sub-Redcap299
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap299
# ._sub-Redcap299
# Processed subject: ._sub-Redcap299
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap3
# sub-Redcap3
# Processed subject: sub-Redcap3
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap3
# ._sub-Redcap3
# Processed subject: ._sub-Redcap3
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap30
# sub-Redcap30
# Processed subject: sub-Redcap30
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap30
# ._sub-Redcap30
# Processed subject: ._sub-Redcap30
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap300
# sub-Redcap300
# Processed subject: sub-Redcap300
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap300
# ._sub-Redcap300
# Processed subject: ._sub-Redcap300
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap301
# sub-Redcap301
# Processed subject: sub-Redcap301
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap301
# ._sub-Redcap301
# Processed subject: ._sub-Redcap301
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap302
# sub-Redcap302
# Processed subject: sub-Redcap302
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap302
# ._sub-Redcap302
# Processed subject: ._sub-Redcap302
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap303
# sub-Redcap303
# Processed subject: sub-Redcap303
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap303
# ._sub-Redcap303
# Processed subject: ._sub-Redcap303
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap304
# sub-Redcap304
# Processed subject: sub-Redcap304
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap304
# ._sub-Redcap304
# Processed subject: ._sub-Redcap304
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap305
# sub-Redcap305
# Processed subject: sub-Redcap305
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap305
# ._sub-Redcap305
# Processed subject: ._sub-Redcap305
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap306
# sub-Redcap306
# Processed subject: sub-Redcap306
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap306
# ._sub-Redcap306
# Processed subject: ._sub-Redcap306
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap307
# sub-Redcap307
# Processed subject: sub-Redcap307
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap307
# ._sub-Redcap307
# Processed subject: ._sub-Redcap307
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap308
# sub-Redcap308
# Processed subject: sub-Redcap308
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap308
# ._sub-Redcap308
# Processed subject: ._sub-Redcap308
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap309
# sub-Redcap309
# Processed subject: sub-Redcap309
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap309
# ._sub-Redcap309
# Processed subject: ._sub-Redcap309
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap31
# sub-Redcap31
# Processed subject: sub-Redcap31
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap31
# ._sub-Redcap31
# Processed subject: ._sub-Redcap31
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap310
# sub-Redcap310
# Processed subject: sub-Redcap310
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap310
# ._sub-Redcap310
# Processed subject: ._sub-Redcap310
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap311
# sub-Redcap311
# Processed subject: sub-Redcap311
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap311
# ._sub-Redcap311
# Processed subject: ._sub-Redcap311
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap312
# sub-Redcap312
# Processed subject: sub-Redcap312
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap312
# ._sub-Redcap312
# Processed subject: ._sub-Redcap312
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap313
# sub-Redcap313
# Processed subject: sub-Redcap313
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap313
# ._sub-Redcap313
# Processed subject: ._sub-Redcap313
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap316
# sub-Redcap316
# Processed subject: sub-Redcap316
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap316
# ._sub-Redcap316
# Processed subject: ._sub-Redcap316
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap317
# sub-Redcap317
# Processed subject: sub-Redcap317
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap317
# ._sub-Redcap317
# Processed subject: ._sub-Redcap317
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap32
# sub-Redcap32
# Processed subject: sub-Redcap32
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap32
# ._sub-Redcap32
# Processed subject: ._sub-Redcap32
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap320
# sub-Redcap320
# Processed subject: sub-Redcap320
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap320
# ._sub-Redcap320
# Processed subject: ._sub-Redcap320
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap321
# sub-Redcap321
# Processed subject: sub-Redcap321
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap321
# ._sub-Redcap321
# Processed subject: ._sub-Redcap321
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap322
# sub-Redcap322
# Processed subject: sub-Redcap322
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap322
# ._sub-Redcap322
# Processed subject: ._sub-Redcap322
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap323
# sub-Redcap323
# Processed subject: sub-Redcap323
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap323
# ._sub-Redcap323
# Processed subject: ._sub-Redcap323
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap324
# sub-Redcap324
# Processed subject: sub-Redcap324
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap324
# ._sub-Redcap324
# Processed subject: ._sub-Redcap324
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap325
# sub-Redcap325
# Processed subject: sub-Redcap325
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap325
# ._sub-Redcap325
# Processed subject: ._sub-Redcap325
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap328
# sub-Redcap328
# Processed subject: sub-Redcap328
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap328
# ._sub-Redcap328
# Processed subject: ._sub-Redcap328
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap329
# sub-Redcap329
# Processed subject: sub-Redcap329
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap329
# ._sub-Redcap329
# Processed subject: ._sub-Redcap329
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap33
# sub-Redcap33
# Processed subject: sub-Redcap33
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap33
# ._sub-Redcap33
# Processed subject: ._sub-Redcap33
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap330
# sub-Redcap330
# Processed subject: sub-Redcap330
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap330
# ._sub-Redcap330
# Processed subject: ._sub-Redcap330
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap331
# sub-Redcap331
# Processed subject: sub-Redcap331
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap331
# ._sub-Redcap331
# Processed subject: ._sub-Redcap331
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap332
# sub-Redcap332
# Processed subject: sub-Redcap332
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap332
# ._sub-Redcap332
# Processed subject: ._sub-Redcap332
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap333
# sub-Redcap333
# Processed subject: sub-Redcap333
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap333
# ._sub-Redcap333
# Processed subject: ._sub-Redcap333
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap335
# sub-Redcap335
# Processed subject: sub-Redcap335
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap335
# ._sub-Redcap335
# Processed subject: ._sub-Redcap335
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap336
# sub-Redcap336
# Processed subject: sub-Redcap336
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap336
# ._sub-Redcap336
# Processed subject: ._sub-Redcap336
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap34
# sub-Redcap34
# Processed subject: sub-Redcap34
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap34
# ._sub-Redcap34
# Processed subject: ._sub-Redcap34
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap340
# sub-Redcap340
# Processed subject: sub-Redcap340
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap340
# ._sub-Redcap340
# Processed subject: ._sub-Redcap340
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap342
# sub-Redcap342
# Processed subject: sub-Redcap342
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap342
# ._sub-Redcap342
# Processed subject: ._sub-Redcap342
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap344
# sub-Redcap344
# Processed subject: sub-Redcap344
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap344
# ._sub-Redcap344
# Processed subject: ._sub-Redcap344
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap35
# sub-Redcap35
# Processed subject: sub-Redcap35
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap35
# ._sub-Redcap35
# Processed subject: ._sub-Redcap35
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap356
# sub-Redcap356
# Processed subject: sub-Redcap356
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap356
# ._sub-Redcap356
# Processed subject: ._sub-Redcap356
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap357
# sub-Redcap357
# Processed subject: sub-Redcap357
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap357
# ._sub-Redcap357
# Processed subject: ._sub-Redcap357
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap36
# sub-Redcap36
# Processed subject: sub-Redcap36
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap36
# ._sub-Redcap36
# Processed subject: ._sub-Redcap36
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap369
# sub-Redcap369
# Processed subject: sub-Redcap369
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap369
# ._sub-Redcap369
# Processed subject: ._sub-Redcap369
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap37
# sub-Redcap37
# Processed subject: sub-Redcap37
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap37
# ._sub-Redcap37
# Processed subject: ._sub-Redcap37
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap371
# sub-Redcap371
# Processed subject: sub-Redcap371
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap371
# ._sub-Redcap371
# Processed subject: ._sub-Redcap371
# ...
# sub-Redcap450
# Processed subject: sub-Redcap450
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap450
# ._sub-Redcap450
# Processed subject: ._sub-Redcap450
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap452
# sub-redcap452
# Processed subject: sub-redcap452
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap452
# ._sub-redcap452
# Processed subject: ._sub-redcap452
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap454
# sub-Redcap454
# Processed subject: sub-Redcap454
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap454
# ._sub-Redcap454
# Processed subject: ._sub-Redcap454
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap460
# sub-Redcap460
# Processed subject: sub-Redcap460
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap460
# ._sub-Redcap460
# Processed subject: ._sub-Redcap460
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap461
# sub-Redcap461
# Processed subject: sub-Redcap461
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap461
# ._sub-Redcap461
# Processed subject: ._sub-Redcap461
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap462
# sub-redcap462
# Processed subject: sub-redcap462
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap462
# ._sub-redcap462
# Processed subject: ._sub-redcap462
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap463
# sub-Redcap463
# Processed subject: sub-Redcap463
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap463
# ._sub-Redcap463
# Processed subject: ._sub-Redcap463
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap464
# sub-redcap464
# Processed subject: sub-redcap464
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap464
# ._sub-redcap464
# Processed subject: ._sub-redcap464
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap467
# sub-redcap467
# Processed subject: sub-redcap467
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap467
# ._sub-redcap467
# Processed subject: ._sub-redcap467
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap468
# sub-Redcap468
# Processed subject: sub-Redcap468
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap468
# ._sub-Redcap468
# Processed subject: ._sub-Redcap468
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap469
# sub-Redcap469
# Processed subject: sub-Redcap469
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap469
# ._sub-Redcap469
# Processed subject: ._sub-Redcap469
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap471
# sub-Redcap471
# Processed subject: sub-Redcap471
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap471
# ._sub-Redcap471
# Processed subject: ._sub-Redcap471
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap472
# sub-Redcap472
# Processed subject: sub-Redcap472
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap472
# ._sub-Redcap472
# Processed subject: ._sub-Redcap472
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap473
# sub-Redcap473
# Processed subject: sub-Redcap473
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap473
# ._sub-Redcap473
# Processed subject: ._sub-Redcap473
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap474
# sub-redcap474
# Processed subject: sub-redcap474
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap474
# ._sub-redcap474
# Processed subject: ._sub-redcap474
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap475
# sub-redcap475
# Processed subject: sub-redcap475
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap475
# ._sub-redcap475
# Processed subject: ._sub-redcap475
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap476
# sub-redcap476
# Processed subject: sub-redcap476
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap476
# ._sub-redcap476
# Processed subject: ._sub-redcap476
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap478
# sub-Redcap478
# Processed subject: sub-Redcap478
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap478
# ._sub-Redcap478
# Processed subject: ._sub-Redcap478
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap479
# sub-redcap479
# Processed subject: sub-redcap479
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap479
# ._sub-redcap479
# Processed subject: ._sub-redcap479
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap480
# sub-Redcap480
# Processed subject: sub-Redcap480
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap480
# ._sub-Redcap480
# Processed subject: ._sub-Redcap480
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap481
# sub-Redcap481
# Processed subject: sub-Redcap481
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap481
# ._sub-Redcap481
# Processed subject: ._sub-Redcap481
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap482
# sub-Redcap482
# Processed subject: sub-Redcap482
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap482
# ._sub-Redcap482
# Processed subject: ._sub-Redcap482
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap483
# sub-Redcap483
# Processed subject: sub-Redcap483
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap483
# ._sub-Redcap483
# Processed subject: ._sub-Redcap483
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap485
# sub-Redcap485
# Processed subject: sub-Redcap485
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap485
# ._sub-Redcap485
# Processed subject: ._sub-Redcap485
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap487
# sub-Redcap487
# Processed subject: sub-Redcap487
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap487
# ._sub-Redcap487
# Processed subject: ._sub-Redcap487
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap489
# sub-redcap489
# Processed subject: sub-redcap489
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap489
# ._sub-redcap489
# Processed subject: ._sub-redcap489
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap490
# sub-redcap490
# Processed subject: sub-redcap490
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap490
# ._sub-redcap490
# Processed subject: ._sub-redcap490
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap491
# sub-redcap491
# Processed subject: sub-redcap491
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap491
# ._sub-redcap491
# Processed subject: ._sub-redcap491
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap492
# sub-redcap492
# Processed subject: sub-redcap492
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap492
# ._sub-redcap492
# Processed subject: ._sub-redcap492
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap493
# sub-redcap493
# Processed subject: sub-redcap493
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap493
# ._sub-redcap493
# Processed subject: ._sub-redcap493
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap495
# sub-redcap495
# Processed subject: sub-redcap495
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap495
# ._sub-redcap495
# Processed subject: ._sub-redcap495
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap496
# sub-redcap496
# Processed subject: sub-redcap496
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap496
# ._sub-redcap496
# Processed subject: ._sub-redcap496
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap498
# sub-redcap498
# Processed subject: sub-redcap498
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap498
# ._sub-redcap498
# Processed subject: ._sub-redcap498
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap499
# sub-redcap499
# Processed subject: sub-redcap499
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap499
# ._sub-redcap499
# Processed subject: ._sub-redcap499
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap502
# sub-redcap502
# Processed subject: sub-redcap502
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap502
# ._sub-redcap502
# Processed subject: ._sub-redcap502
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap503
# sub-redcap503
# Processed subject: sub-redcap503
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap503
# ._sub-redcap503
# Processed subject: ._sub-redcap503
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap504
# sub-redcap504
# Processed subject: sub-redcap504
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap504
# ._sub-redcap504
# Processed subject: ._sub-redcap504
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap505
# sub-redcap505
# Processed subject: sub-redcap505
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap505
# ._sub-redcap505
# Processed subject: ._sub-redcap505
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap506
# sub-redcap506
# Processed subject: sub-redcap506
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap506
# ._sub-redcap506
# Processed subject: ._sub-redcap506
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap556
# sub-redcap556
# Processed subject: sub-redcap556
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap556
# ._sub-redcap556
# Processed subject: ._sub-redcap556
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap508
# sub-redcap508
# Processed subject: sub-redcap508
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap508
# ._sub-redcap508
# Processed subject: ._sub-redcap508
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap509
# sub-redcap509
# Processed subject: sub-redcap509
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap509
# ._sub-redcap509
# Processed subject: ._sub-redcap509
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap512
# sub-redcap512
# Processed subject: sub-redcap512
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap512
# ._sub-redcap512
# Processed subject: ._sub-redcap512
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap513
# sub-redcap513
# Processed subject: sub-redcap513
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap513
# ._sub-redcap513
# Processed subject: ._sub-redcap513
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap515
# sub-redcap515
# Processed subject: sub-redcap515
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap515
# ._sub-redcap515
# Processed subject: ._sub-redcap515
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap516
# sub-redcap516
# Processed subject: sub-redcap516
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap516
# ._sub-redcap516
# Processed subject: ._sub-redcap516
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap517
# sub-redcap517
# Processed subject: sub-redcap517
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap517
# ._sub-redcap517
# Processed subject: ._sub-redcap517
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap518
# sub-redcap518
# Processed subject: sub-redcap518
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap518
# ._sub-redcap518
# Processed subject: ._sub-redcap518
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap520
# sub-redcap520
# Processed subject: sub-redcap520
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap520
# ._sub-redcap520
# Processed subject: ._sub-redcap520
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap521
# sub-redcap521
# Processed subject: sub-redcap521
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap521
# ._sub-redcap521
# Processed subject: ._sub-redcap521
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap522
# sub-redcap522
# Processed subject: sub-redcap522
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap522
# ._sub-redcap522
# Processed subject: ._sub-redcap522
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap524
# sub-redcap524
# Processed subject: sub-redcap524
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap524
# ._sub-redcap524
# Processed subject: ._sub-redcap524
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap527
# sub-redcap527
# Processed subject: sub-redcap527
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap527
# ._sub-redcap527
# Processed subject: ._sub-redcap527
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap528
# sub-redcap528
# Processed subject: sub-redcap528
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap528
# ._sub-redcap528
# Processed subject: ._sub-redcap528
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap529
# sub-redcap529
# Processed subject: sub-redcap529
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap529
# ._sub-redcap529
# Processed subject: ._sub-redcap529
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap530
# sub-redcap530
# Processed subject: sub-redcap530
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap530
# ._sub-redcap530
# Processed subject: ._sub-redcap530
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap531
# sub-redcap531
# Processed subject: sub-redcap531
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap531
# ._sub-redcap531
# Processed subject: ._sub-redcap531
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap532
# sub-redcap532
# Processed subject: sub-redcap532
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap532
# ._sub-redcap532
# Processed subject: ._sub-redcap532
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap533
# sub-redcap533
# Processed subject: sub-redcap533
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap533
# ._sub-redcap533
# Processed subject: ._sub-redcap533
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap534
# sub-redcap534
# Processed subject: sub-redcap534
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap534
# ._sub-redcap534
# Processed subject: ._sub-redcap534
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap535
# sub-redcap535
# Processed subject: sub-redcap535
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap535
# ._sub-redcap535
# Processed subject: ._sub-redcap535
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap537
# sub-redcap537
# Processed subject: sub-redcap537
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap537
# ._sub-redcap537
# Processed subject: ._sub-redcap537
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap539
# sub-redcap539
# Processed subject: sub-redcap539
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap539
# ._sub-redcap539
# Processed subject: ._sub-redcap539
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap540
# sub-redcap540
# Processed subject: sub-redcap540
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap540
# ._sub-redcap540
# Processed subject: ._sub-redcap540
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap542
# sub-redcap542
# Processed subject: sub-redcap542
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap542
# ._sub-redcap542
# Processed subject: ._sub-redcap542
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap543
# sub-redcap543
# Processed subject: sub-redcap543
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap543
# ._sub-redcap543
# Processed subject: ._sub-redcap543
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap544
# sub-redcap544
# Processed subject: sub-redcap544
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap544
# ._sub-redcap544
# Processed subject: ._sub-redcap544
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap546
# sub-redcap546
# Processed subject: sub-redcap546
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap546
# ._sub-redcap546
# Processed subject: ._sub-redcap546
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-Redcap547
# sub-Redcap547
# Processed subject: sub-Redcap547
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-Redcap547
# ._sub-Redcap547
# Processed subject: ._sub-Redcap547
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap548
# sub-redcap548
# Processed subject: sub-redcap548
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap548
# ._sub-redcap548
# Processed subject: ._sub-redcap548
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap549
# sub-redcap549
# Processed subject: sub-redcap549
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap549
# ._sub-redcap549
# Processed subject: ._sub-redcap549
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap550
# sub-redcap550
# Processed subject: sub-redcap550
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap550
# ._sub-redcap550
# Processed subject: ._sub-redcap550
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap551
# sub-redcap551
# Processed subject: sub-redcap551
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap551
# ._sub-redcap551
# Processed subject: ._sub-redcap551
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap552
# sub-redcap552
# Processed subject: sub-redcap552
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap552
# ._sub-redcap552
# Processed subject: ._sub-redcap552
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap553
# sub-redcap553
# Processed subject: sub-redcap553
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap553
# ._sub-redcap553
# Processed subject: ._sub-redcap553
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap554
# sub-redcap554
# Processed subject: sub-redcap554
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap554
# ._sub-redcap554
# Processed subject: ._sub-redcap554
# /Volumes/HowExp/datasets/HIFUS_minisets/sub-redcap555
# sub-redcap555
# Processed subject: sub-redcap555
# /Volumes/HowExp/datasets/HIFUS_minisets/._sub-redcap555
# ._sub-redcap555
# Processed subject: ._sub-redcap555

# %%
t = '.dogs'
t[0]
